# %%
import pandas as pd

# %%
df = pd.read_csv('all_combined.csv')

# %%
df.info
# Out:
# <bound method DataFrame.info of            C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0         A002  R051  02-00-00          59 ST  NQR456W      BMT  12/29/2018
# 1         A002  R051  02-00-00          59 ST  NQR456W      BMT  12/29/2018
# 2         A002  R051  02-00-00          59 ST  NQR456W      BMT  12/29/2018
# 3         A002  R051  02-00-00          59 ST  NQR456W      BMT  12/29/2018
# 4         A002  R051  02-00-00          59 ST  NQR456W      BMT  12/29/2018
# ...        ...   ...       ...            ...      ...      ...         ...
# 2667716  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/03/2020
# 2667717  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/03/2020
# 2667718  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/03/2020
# 2667719  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/03/2020
# 2667720  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/03/2020
#
# ...

# %%
df.sample(20, random_state = 7)
# Out:
#            C/A  UNIT       SCP          STATION  LINENAME DIVISION  \
# 800244    R606  R225  00-00-01          HOYT ST        23      IRT
# 163624    R260  R205  01-05-01   149/GRAND CONC       245      IRT
# 1206614  R532H  R328  02-03-03  METS-WILLETS PT         7      IRT
# 2458423   R647  R110  02-00-00  FLATBUSH AV-B.C        25      IRT
# 729414   PTH18  R549  01-00-05     NEWARK BM BW         1      PTH
# 635384    E011  R371  00-00-00            79 ST         D      BMT
# 2439862   R510  R090  00-03-02            39 AV       NQW      BMT
# 152437    R221  R170  01-06-03   14 ST-UNION SQ  456LNQRW      IRT
# 1494661   N102  R127  01-05-01  JAY ST-METROTEC       ACF      IND
# 2578030  PTH02  R544  00-06-06         HARRISON         1      PTH
# 1681530  N006A  R280  00-00-00           190 ST         A      IND
# 589810    R525  R018  02-00-00   74 ST-BROADWAY     7EFMR      IRT
# 1157082   R159  R164  01-00-01    66 ST-LINCOLN         1      IRT
# ...

# %%
jan = df[(df['date'] > '01/01/2019') & (df['date'] <= '01/31/2019')].reset_index()

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a74c58233b9e> in <module>
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df.describe()
# Out:
#             ENTRIES  \
# count  2.667721e+06
# mean   4.146011e+07
# std    2.125462e+08
# min    0.000000e+00
# 25%    3.384680e+05
# 50%    2.152062e+06
# 75%    6.729144e+06
# max    2.129552e+09
#
#        EXITS
# count                                       2.667721e+06
# mean                                        3.408465e+07
# std                                         1.959693e+08
# min                                         0.000000e+00
# 25%                                         1.436140e+05
# 50%                                         1.245234e+06
# 75%                                         4.609500e+06
# max                                         2.124342e+09

# %%
df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2667721 entries, 0 to 2667720
# Data columns (total 11 columns):
#  #   Column                                                                Non-Null Count    Dtype
# ---  ------                                                                --------------    -----
#  0   C/A                                                                   2667721 non-null  object
#  1   UNIT                                                                  2667721 non-null  object
#  2   SCP                                                                   2667721 non-null  object
#  3   STATION                                                               2667721 non-null  object
#  4   LINENAME                                                              2667721 non-null  object
#  5   DIVISION                                                              2667721 non-null  object
# ...

# %%
df.dtypes
# Out:
# C/A                                                                     object
# UNIT                                                                    object
# SCP                                                                     object
# STATION                                                                 object
# LINENAME                                                                object
# DIVISION                                                                object
# DATE                                                                    object
# TIME                                                                    object
# DESC                                                                    object
# ENTRIES                                                                  int64
# EXITS                                                                    int64
# dtype: object

# %%
df.UNIT.nunique()
# Out:
# 470

# %%
df.STATION.tail(20)
# Out:
# 2667701    RIT-ROOSEVELT
# 2667702    RIT-ROOSEVELT
# 2667703    RIT-ROOSEVELT
# 2667704    RIT-ROOSEVELT
# 2667705    RIT-ROOSEVELT
# 2667706    RIT-ROOSEVELT
# 2667707    RIT-ROOSEVELT
# 2667708    RIT-ROOSEVELT
# 2667709    RIT-ROOSEVELT
# 2667710    RIT-ROOSEVELT
# 2667711    RIT-ROOSEVELT
# 2667712    RIT-ROOSEVELT
# 2667713    RIT-ROOSEVELT
# 2667714    RIT-ROOSEVELT
# 2667715    RIT-ROOSEVELT
# 2667716    RIT-ROOSEVELT
# 2667717    RIT-ROOSEVELT
# 2667718    RIT-ROOSEVELT
# 2667719    RIT-ROOSEVELT
# 2667720    RIT-ROOSEVELT
# Name: STATION, dtype: object

# %%
df.STATION.nunique()
# Out:
# 379

# %%
df['C/A'].nunique()
# Out:
# 750

# %%
feb=df[(df['date'] > '01/31/2019') & (df['date']< '03/01/2019')].reset_index()

# %%
feb19
# Out:
#          index    C/A  UNIT       SCP        STATION LINENAME DIVISION  \
# 0       201639   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 1       201640   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 2       201641   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 3       201642   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 4       201643   A002  R051  02-00-00          59 ST  NQR456W      BMT
# ...        ...    ...   ...       ...            ...      ...      ...
# 203664  607693  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 203665  607694  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 203666  607695  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 203667  607696  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 203668  607697  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
#
#               DATE      TIME     DESC  ENTRIES  \
# 0       02/01/2019  03:00:00  REGULAR  6929470
# ...

# %%
feb19.iloc[201639,'EXITS']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     701             try:
# --> 702                 self._validate_key(k, i)
#     703             except ValueError as err:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1368         else:
# -> 1369             raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#    1370
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-0a7850055235> in <module>
# ...

# %%
jan19.loc[0,'ENTRIES']
# Out:
# 6892452

# %%
diff_try = (feb.loc[0,'ENTRIES']-jan.loc[0,'ENTRIES'])

# %%
diff_try
# Out:
# 37018

# %%
jan.head(2)
# Out:
#    index   C/A  UNIT       SCP STATION LINENAME DIVISION        DATE  \
# 0     24  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/02/2019
# 1     25  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/02/2019
#
#        TIME     DESC  ENTRIES  \
# 0  03:00:00  REGULAR  6892452
# 1  07:00:00  REGULAR  6892467
#
#    EXITS
# 0                                            2336895
# 1                                            2336934

# %%
jan.STATION.nunique()
# Out:
# 378

# %%
totalj = jan.groupby(['STATION']).sum(['ENTRIES'])

# %%
totalj
# Out:
#                       index       ENTRIES  \
# STATION
# 1 AV              537914340  172453990293
# 103 ST            933336834   11025080606
# 103 ST-CORONA     615834342    5449445934
# 104 ST            499834476  292250350451
# 110 ST            388557747    2738580276
# ...                     ...           ...
# WOODLAWN          318383892    2179816099
# WORLD TRADE CTR  1004245656  114990895588
# WTC-CORTLANDT    2145369941   52828148744
# YORK ST           176642046    3032475369
# ZEREGA AV         385949154     128101951
#
#                  EXITS
# STATION
# 1 AV                                                   96024709054
# 103 ST                                                 34745119177
# 103 ST-CORONA                                           5491763289
# 104 ST                                                208360803538
# 110 ST                                                  2622437035
# ...                                                            ...
# ...

# %%
mar =df[(df['DATE'] > '2/31/2019') & (df['DATE']< '04/01/2019')].reset_index()

# %%
apr = df[(df['DATE'] > '03/31/2019') & (df['DATE']< '05/01/2019')].reset_index()

# %%
may = df[(df['DATE'] > '04/31/2019') & (df['DATE']< '06/01/2019')].reset_index()

# %%
jun = df[(df['DATE'] > '05/31/2019') & (df['DATE']< '07/01/2019')].reset_index()

# %%
jul =df[(df['DATE'] > '06/31/2019') & (df['DATE']< '08/01/2019')].reset_index()

# %%
aug = df[(df['DATE'] > '07/31/2019') & (df['DATE']< '09/01/2019')].reset_index()

# %%
df.groupby('STATION').head(50)
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  12/29/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  12/29/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  12/29/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  12/29/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  12/29/2018
# ...       ...   ...       ...            ...      ...      ...         ...
# 1130790  OB01  R459  00-00-01  ORCHARD BEACH        6      IND  05/25/2019
# 1130791  OB01  R459  00-00-01  ORCHARD BEACH        6      IND  05/25/2019
# 1130792  OB01  R459  00-00-01  ORCHARD BEACH        6      IND  05/25/2019
# 1130793  OB01  R459  00-00-01  ORCHARD BEACH        6      IND  05/26/2019
# 1130794  OB01  R459  00-00-01  ORCHARD BEACH        6      IND  05/26/2019
#
#              TIME     DESC  ENTRIES  \
# ...

# %%
df.STATION.unique()
# Out:
# array(['59 ST', '5 AV/59 ST', '57 ST-7 AV', '49 ST', 'TIMES SQ-42 ST',
#        '34 ST-HERALD SQ', '28 ST', '23 ST', '14 ST-UNION SQ', '8 ST-NYU',
#        'PRINCE ST', 'CANAL ST', 'CITY HALL', 'CORTLANDT ST', 'RECTOR ST',
#        'WHITEHALL S-FRY', 'DELANCEY/ESSEX', 'BOWERY', 'CHAMBERS ST',
#        'FULTON ST', 'BROAD ST', '7 AV', 'PARK PLACE', 'BOTANIC GARDEN',
#        'PROSPECT PARK', 'PARKSIDE AV', 'CHURCH AV', 'BEVERLEY ROAD',
#        'CORTELYOU RD', 'NEWKIRK PLAZA', 'AVENUE H', 'AVENUE J',
#        'AVENUE M', 'KINGS HWY', 'AVENUE U', 'NECK RD', 'SHEEPSHEAD BAY',
#        'BRIGHTON BEACH', 'OCEAN PKWY', 'BOROUGH HALL', 'JAY ST-METROTEC',
#        'DEKALB AV', 'ATL AV-BARCLAY', 'UNION ST', '4AV-9 ST',
#        'PROSPECT AV', '25 ST', '36 ST', '45 ST', '53 ST', 'BAY RIDGE AV',
#        '77 ST', '86 ST', 'BAY RIDGE-95 ST', '8 AV', 'FT HAMILTON PKY',
#        'NEW UTRECHT AV', '18 AV', '20 AV', 'BAY PKWY', '9 AV', '50 ST',
# ...

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (2667721, 11)

# %%
df.rename(columns={'c/a':'ca'})
# Out:
#            C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0         A002  R051  02-00-00          59 ST  NQR456W      BMT  12/29/2018
# 1         A002  R051  02-00-00          59 ST  NQR456W      BMT  12/29/2018
# 2         A002  R051  02-00-00          59 ST  NQR456W      BMT  12/29/2018
# 3         A002  R051  02-00-00          59 ST  NQR456W      BMT  12/29/2018
# 4         A002  R051  02-00-00          59 ST  NQR456W      BMT  12/29/2018
# ...        ...   ...       ...            ...      ...      ...         ...
# 2667716  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/03/2020
# 2667717  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/03/2020
# 2667718  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/03/2020
# 2667719  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/03/2020
# 2667720  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/03/2020
#
#              TIME     DESC  ENTRIES    EXITS
# ...

# %%
df.head()
# Out:
#      ca  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/29/2018  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/29/2018  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/29/2018  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/29/2018  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/29/2018  19:00:00
#
#       desc  entries    exits
# 0  REGULAR  6889287  2335920
# 1  REGULAR  6889299  2335936
# 2  REGULAR  6889364  2336038
# 3  REGULAR  6889605  2336101
# 4  REGULAR  6889966  2336173

# %%
df.columns = df.columns.str.lower()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2667721 entries, 0 to 2667720
# Data columns (total 11 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   ca        object
#  1   unit      object
#  2   scp       object
#  3   station   object
#  4   linename  object
#  5   division  object
#  6   date      object
#  7   time      object
#  8   desc      object
#  9   entries   int64
#  10  exits     int64
# dtypes: int64(2), object(9)
# memory usage: 223.9+ MB

# %%
df['datetime'] = pd.to_datetime(df.date + ' ' + df.time,
                               format = '%m/%d/%Y %H:%M:%S')

# %%
df.head()
# Out:
#      ca  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/29/2018  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/29/2018  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/29/2018  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/29/2018  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/29/2018  19:00:00
#
#       desc  entries    exits            datetime
# 0  REGULAR  6889287  2335920 2018-12-29 03:00:00
# 1  REGULAR  6889299  2335936 2018-12-29 07:00:00
# 2  REGULAR  6889364  2336038 2018-12-29 11:00:00
# 3  REGULAR  6889605  2336101 2018-12-29 15:00:00
# 4  REGULAR  6889966  2336173 2018-12-29 19:00:00

# %%
df.drop(columns=(['date','time','division','linename']), inplace=True)
# Out:
# /Users/michaelharnett/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.head()
# Out:
#             turnstile station     desc  entries    exits            datetime
# 0  A002 R051 02-00-00   59 ST  REGULAR  6889287  2335920 2018-12-29 03:00:00
# 1  A002 R051 02-00-00   59 ST  REGULAR  6889299  2335936 2018-12-29 07:00:00
# 2  A002 R051 02-00-00   59 ST  REGULAR  6889364  2336038 2018-12-29 11:00:00
# 3  A002 R051 02-00-00   59 ST  REGULAR  6889605  2336101 2018-12-29 15:00:00
# 4  A002 R051 02-00-00   59 ST  REGULAR  6889966  2336173 2018-12-29 19:00:00

# %%
df.pop('turnstile')
# Out:
# 0           A002 R051 02-00-00
# 1           A002 R051 02-00-00
# 2           A002 R051 02-00-00
# 3           A002 R051 02-00-00
# 4           A002 R051 02-00-00
#                   ...
# 2667716    TRAM2 R469 00-05-01
# 2667717    TRAM2 R469 00-05-01
# 2667718    TRAM2 R469 00-05-01
# 2667719    TRAM2 R469 00-05-01
# 2667720    TRAM2 R469 00-05-01
# Name: turnstile, Length: 2667721, dtype: object

# %%
df.insert(0,(df.pop)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-dc1231e4f0ec> in <module>
# ----> 1 df.insert(0,(df.pop('turnstile')))
#
# TypeError: insert() missing 1 required positional argument: 'value'

# %%
list(df)
# Out:
# ['turnstile', 'station', 'desc', 'entries', 'exits', 'datetime']

# %%
cols = list(df)

# %%
cols=(list(df))

# %%
cols.insert(1, cols.pop(cols.index('datetime')))

# %%
df = df[cols]

# %%
df.desc.value_counts()
# Out:
# REGULAR       2658197
# RECOVR AUD       9524
# Name: desc, dtype: int64

# %%
df2.drop(columns=['c/a','unit','scp'],inplace=True)
# Out:
# /Users/michaelharnett/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.groupby(['station'])[['turnstile']].nunique().turnstile.sort_values(ascending=False)
# Out:
# station
# 34 ST-PENN STA     109
# FULTON ST           96
# GRD CNTRL-42 ST     75
# 23 ST               73
# 86 ST               63
#                   ...
# NORWOOD AV           3
# STERLING ST          3
# YORK ST              3
# CLEVELAND ST         2
# SUTTER AV            2
# Name: turnstile, Length: 379, dtype: int64

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-101-2068723f1203> in <module>
# ----> 1 df2
#
# NameError: name 'df2' is not defined

# %%
try_station.head()
# Out:
#                   term_id   c/a  unit       scp       station linename  \
# 0        A002R05102-00-00  A002  R051  02-00-00         59 ST  NQR456W
# 1        A002R05102-00-00  A002  R051  02-00-00         59 ST  NQR456W
# 2        A002R05102-00-00  A002  R051  02-00-00         59 ST  NQR456W
# 3        A002R05102-00-00  A002  R051  02-00-00         59 ST  NQR456W
# 4        A002R05102-00-00  A002  R051  02-00-00         59 ST  NQR456W
# ...                   ...   ...   ...       ...           ...      ...
# 2647168  R514R09400-06-01  R514  R094  00-06-01  ASTORIA BLVD      NQW
# 2647169  R514R09400-06-01  R514  R094  00-06-01  ASTORIA BLVD      NQW
# 2647170  R514R09400-06-01  R514  R094  00-06-01  ASTORIA BLVD      NQW
# 2647171  R514R09400-06-01  R514  R094  00-06-01  ASTORIA BLVD      NQW
# 2647172  R514R09400-06-01  R514  R094  00-06-01  ASTORIA BLVD      NQW
#
#         division        date      time     desc  entries  \
# ...

# %% [raw]
# df2

# %%
df2['group_nums'] = df2.groupby('turnstile').ngroup()
# Out:
# <ipython-input-108-bd4b533eb019>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['group_nums'] = df2.groupby('turnstile').ngroup()

# %%
df2
# Out:
#                    turnstile            datetime        station     desc  \
# 0         A002 R051 02-00-00 2018-12-29 03:00:00          59 ST  REGULAR
# 1         A002 R051 02-00-00 2018-12-29 07:00:00          59 ST  REGULAR
# 2         A002 R051 02-00-00 2018-12-29 11:00:00          59 ST  REGULAR
# 3         A002 R051 02-00-00 2018-12-29 15:00:00          59 ST  REGULAR
# 4         A002 R051 02-00-00 2018-12-29 19:00:00          59 ST  REGULAR
# ...                      ...                 ...            ...      ...
# 2667716  TRAM2 R469 00-05-01 2020-01-03 04:00:00  RIT-ROOSEVELT  REGULAR
# 2667717  TRAM2 R469 00-05-01 2020-01-03 08:00:00  RIT-ROOSEVELT  REGULAR
# 2667718  TRAM2 R469 00-05-01 2020-01-03 12:00:00  RIT-ROOSEVELT  REGULAR
# 2667719  TRAM2 R469 00-05-01 2020-01-03 16:00:00  RIT-ROOSEVELT  REGULAR
# 2667720  TRAM2 R469 00-05-01 2020-01-03 20:00:00  RIT-ROOSEVELT  REGULAR
#
#          entries    exits  group_nums
# 0        6889287  2335920           0
# ...

# %%
jan = df2[(df2['date'] >= '01/01/2019') & (df['date'] < '02/01/2019')].
# Out:
#                   term_id   c/a  unit       scp       station linename  \
# 0        A002R05102-00-00  A002  R051  02-00-00         59 ST  NQR456W
# 1        A002R05102-00-00  A002  R051  02-00-00         59 ST  NQR456W
# 2        A002R05102-00-00  A002  R051  02-00-00         59 ST  NQR456W
# 3        A002R05102-00-00  A002  R051  02-00-00         59 ST  NQR456W
# 4        A002R05102-00-00  A002  R051  02-00-00         59 ST  NQR456W
# ...                   ...   ...   ...       ...           ...      ...
# 2647168  R514R09400-06-01  R514  R094  00-06-01  ASTORIA BLVD      NQW
# 2647169  R514R09400-06-01  R514  R094  00-06-01  ASTORIA BLVD      NQW
# 2647170  R514R09400-06-01  R514  R094  00-06-01  ASTORIA BLVD      NQW
# 2647171  R514R09400-06-01  R514  R094  00-06-01  ASTORIA BLVD      NQW
# 2647172  R514R09400-06-01  R514  R094  00-06-01  ASTORIA BLVD      NQW
#
#         division        date      time     desc  entries  \
# ...

# %% [markdown]
# df2

# %%
df2
# Out:
#                    term_id    c/a  unit       scp        station linename  \
# 0         A002R05102-00-00   A002  R051  02-00-00          59 ST  NQR456W
# 1         A002R05102-00-00   A002  R051  02-00-00          59 ST  NQR456W
# 2         A002R05102-00-00   A002  R051  02-00-00          59 ST  NQR456W
# 3         A002R05102-00-00   A002  R051  02-00-00          59 ST  NQR456W
# 4         A002R05102-00-00   A002  R051  02-00-00          59 ST  NQR456W
# ...                    ...    ...   ...       ...            ...      ...
# 2667716  TRAM2R46900-05-01  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 2667717  TRAM2R46900-05-01  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 2667718  TRAM2R46900-05-01  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 2667719  TRAM2R46900-05-01  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 2667720  TRAM2R46900-05-01  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#
#         division        date      time     desc  entries  \
# ...

# %%
df2
# Out:
#                    term_id    c/a  unit       scp        station linename  \
# 0         A002R05102-00-00   A002  R051  02-00-00          59 ST  NQR456W
# 1         A002R05102-00-00   A002  R051  02-00-00          59 ST  NQR456W
# 2         A002R05102-00-00   A002  R051  02-00-00          59 ST  NQR456W
# 3         A002R05102-00-00   A002  R051  02-00-00          59 ST  NQR456W
# 4         A002R05102-00-00   A002  R051  02-00-00          59 ST  NQR456W
# ...                    ...    ...   ...       ...            ...      ...
# 2667716  TRAM2R46900-05-01  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 2667717  TRAM2R46900-05-01  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 2667718  TRAM2R46900-05-01  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 2667719  TRAM2R46900-05-01  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 2667720  TRAM2R46900-05-01  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#
#         division        date      time     desc  entries  \
# ...

# %%
df2
# Out:
#                    term_id        station linename division        date  \
# 0         A002R05102-00-00          59 ST  NQR456W      BMT  12/29/2018
# 1         A002R05102-00-00          59 ST  NQR456W      BMT  12/29/2018
# 2         A002R05102-00-00          59 ST  NQR456W      BMT  12/29/2018
# 3         A002R05102-00-00          59 ST  NQR456W      BMT  12/29/2018
# 4         A002R05102-00-00          59 ST  NQR456W      BMT  12/29/2018
# ...                    ...            ...      ...      ...         ...
# 2667716  TRAM2R46900-05-01  RIT-ROOSEVELT        R      RIT  01/03/2020
# 2667717  TRAM2R46900-05-01  RIT-ROOSEVELT        R      RIT  01/03/2020
# 2667718  TRAM2R46900-05-01  RIT-ROOSEVELT        R      RIT  01/03/2020
# 2667719  TRAM2R46900-05-01  RIT-ROOSEVELT        R      RIT  01/03/2020
# 2667720  TRAM2R46900-05-01  RIT-ROOSEVELT        R      RIT  01/03/2020
#
#              time     desc  entries  \
# 0        03:00:00  REGULAR  6889287
# ...

# %%
df2.groupby(['term_id','date']).max()
# Out:
#                                     station linename division      time  \
# term_id           date
# A002R05102-00-00  01/01/2019          59 ST  NQR456W      BMT  23:00:00
#                   01/01/2020          59 ST  NQR456W      BMT  23:00:00
#                   01/02/2019          59 ST  NQR456W      BMT  23:00:00
#                   01/02/2020          59 ST  NQR456W      BMT  23:00:00
#                   01/03/2019          59 ST  NQR456W      BMT  23:00:00
# ...                                     ...      ...      ...       ...
# TRAM2R46900-05-01 12/29/2019  RIT-ROOSEVELT        R      RIT  20:00:00
#                   12/30/2018  RIT-ROOSEVELT        R      RIT  20:00:00
#                   12/30/2019  RIT-ROOSEVELT        R      RIT  20:00:00
#                   12/31/2018  RIT-ROOSEVELT        R      RIT  20:00:00
#                   12/31/2019  RIT-ROOSEVELT        R      RIT  20:00:00
#
#                                  desc  entries  \
# term_id           date
# ...

# %%
df = df[df.desc == 'REGULAR']
df.desc.value_counts()
# Out:
# REGULAR    2658197
# Name: desc, dtype: int64

# %%
jan = df2[(df2.datetime > '12/31/2018') & (df2.datetime < '01/07/2019')].reset_index()

# %%
feb = df2[(df2.datetime > '01/31/2019')& (df2.datetime < '02/07/2019')].reset_index()

# %%
mar = df2[(df2.datetime > '02/28/2019') & (df2.datetime < '03/08/2019')].reset_index()

# %%
apr = df2[(df2.datetime > '03/31/2019') & (df2.datetime < '04/08/2019')].reset_index()

# %%
may = df2[(df2.datetime > '04/30/2019') & (df2.datetime < '03/08/19')].reset_index()

# %%
df.drop(columns=['group_nums'],inplace=True)

# %%
jan1 = df[(df.datetime == '2019-01-01')].reset_index()
jan1
# Out:
#        index            turnstile   datetime         station   entries  \
# 0       4748   A033 R170 02-00-00 2019-01-01  14 ST-UNION SQ   2058504
# 1       4790   A033 R170 02-00-01 2019-01-01  14 ST-UNION SQ   1810289
# 2       4832   A033 R170 02-00-02 2019-01-01  14 ST-UNION SQ  14202557
# 3       4874   A033 R170 02-00-03 2019-01-01  14 ST-UNION SQ   6077136
# 4       4916   A033 R170 02-00-04 2019-01-01  14 ST-UNION SQ   4939956
# ...      ...                  ...        ...             ...       ...
# 1766  201401  TRAM2 R469 00-00-01 2019-01-01   RIT-ROOSEVELT   2876975
# 1767  201445  TRAM2 R469 00-03-00 2019-01-01   RIT-ROOSEVELT    635516
# 1768  201489  TRAM2 R469 00-03-01 2019-01-01   RIT-ROOSEVELT   3015572
# 1769  201533  TRAM2 R469 00-05-00 2019-01-01   RIT-ROOSEVELT      2838
# 1770  201577  TRAM2 R469 00-05-01 2019-01-01   RIT-ROOSEVELT      5554
#
#          exits
# 0      5184532
# 1      2188156
# 2     13711236
# 3      7085828
# 4      3757483
# ...        ...
# ...

# %%
feb1 = df[(df.datetime == '2019-02-01')].reset_index()
feb1
# Out:
#        index            turnstile   datetime         station   entries  \
# 0     206157   A033 R170 02-00-00 2019-02-01  14 ST-UNION SQ   2090072
# 1     206200   A033 R170 02-00-01 2019-02-01  14 ST-UNION SQ   1866376
# 2     206243   A033 R170 02-00-02 2019-02-01  14 ST-UNION SQ  14270131
# 3     206286   A033 R170 02-00-03 2019-02-01  14 ST-UNION SQ   6172182
# 4     206329   A033 R170 02-00-04 2019-02-01  14 ST-UNION SQ   5076576
# ...      ...                  ...        ...             ...       ...
# 1768  404341  TRAM2 R469 00-00-01 2019-02-01   RIT-ROOSEVELT   2918642
# 1769  404383  TRAM2 R469 00-03-00 2019-02-01   RIT-ROOSEVELT    641235
# 1770  404425  TRAM2 R469 00-03-01 2019-02-01   RIT-ROOSEVELT   3021398
# 1771  404467  TRAM2 R469 00-05-00 2019-02-01   RIT-ROOSEVELT      2850
# 1772  404509  TRAM2 R469 00-05-01 2019-02-01   RIT-ROOSEVELT      5554
#
#          exits
# 0      5262018
# 1      2248359
# 2     13784467
# 3      7206372
# 4      3863436
# ...        ...
# ...

# %%
feb1.groupby(['station'])[['turnstile']].nunique()
# Out:
#                  turnstile
# station
# 103 ST                  15
# 111 ST                   7
# 116 ST                  22
# 116 ST-COLUMBIA          6
# 125 ST                  22
# ...                    ...
# WINTHROP ST              4
# WOODHAVEN BLVD          11
# WTC-CORTLANDT           35
# YORK ST                  3
# ZEREGA AV                6
#
# [176 rows x 1 columns]

# %%
mar1 = df[df.datetime == '2019-03-01']
mar1
# Out:
#                   turnstile   datetime         station   entries     exits
# 409411   A033 R170 02-00-00 2019-03-01  14 ST-UNION SQ   2117780   5334607
# 409453   A033 R170 02-00-01 2019-03-01  14 ST-UNION SQ   1916183   2305572
# 409495   A033 R170 02-00-02 2019-03-01  14 ST-UNION SQ  14331047  13850926
# 409537   A033 R170 02-00-03 2019-03-01  14 ST-UNION SQ   6256372   7314371
# 409579   A033 R170 02-00-04 2019-03-01  14 ST-UNION SQ   5196122   3959878
# ...                     ...        ...             ...       ...       ...
# 607530  TRAM2 R469 00-00-01 2019-03-01   RIT-ROOSEVELT   2944684     34394
# 607572  TRAM2 R469 00-03-00 2019-03-01   RIT-ROOSEVELT    647480     24914
# 607614  TRAM2 R469 00-03-01 2019-03-01   RIT-ROOSEVELT   3027722    390896
# 607656  TRAM2 R469 00-05-00 2019-03-01   RIT-ROOSEVELT      2854        62
# 607698  TRAM2 R469 00-05-01 2019-03-01   RIT-ROOSEVELT      5554       369
#
# [1793 rows x 5 columns]

# %%
# Out:
# R128 R105 01-00-01     1
# N040 R251 00-00-00     1
# R423 R429 00-00-02     1
# R112 R027 02-00-00     1
# R416 R245 00-00-01     1
#                       ..
# R200A R041 01-05-01    1
# R158 R084 00-06-02     1
# N046 R281 00-00-02     1
# R143 R032 02-00-03     1
# R526 R096 00-03-01     1
# Name: turnstile, Length: 2475, dtype: int64

# %%
may1 = df[df.datetime == '2019-05-01']
df.loc['A002 R051 02-00-00','turnstile']

# %%
jul1 = df[df.datetime == '2019-07-01']
jul1
# Out:
#                    turnstile   datetime     station     desc  entries    exits
# 1221331   A002 R051 02-00-00 2019-07-01       59 ST  REGULAR  7118119  2410590
# 1221372   A002 R051 02-00-01 2019-07-01       59 ST  REGULAR  6336454  1420922
# 1221413   A002 R051 02-03-00 2019-07-01       59 ST  REGULAR  1252554  4712984
# 1221455   A002 R051 02-03-01 2019-07-01       59 ST  REGULAR  1157180  1783955
# 1221496   A002 R051 02-03-02 2019-07-01       59 ST  REGULAR  6242587  8399054
# ...                      ...        ...         ...      ...      ...      ...
# 1429871  S101A R070 01-03-01 2019-07-01  ST. GEORGE  REGULAR  2041122      215
# 1429913  S101A R070 01-03-02 2019-07-01  ST. GEORGE  REGULAR   492165       21
# 1429955  S101A R070 01-03-03 2019-07-01  ST. GEORGE  REGULAR   137122       24
# 1429997  S101A R070 01-05-00 2019-07-01  ST. GEORGE  REGULAR     1001        0
# 1430039  S101A R070 01-05-01 2019-07-01  ST. GEORGE  REGULAR      657        0
#
# [2468 rows x 6 columns]

# %%
aug1 = df[df.datetime == '2019-08-01']
aug1
# Out:
#                    turnstile   datetime     station     desc  entries    exits
# 1430888   A002 R051 02-00-00 2019-08-01       59 ST  REGULAR  7153768  2420925
# 1430930   A002 R051 02-00-01 2019-08-01       59 ST  REGULAR  6366387  1427064
# 1430972   A002 R051 02-03-00 2019-08-01       59 ST  REGULAR  1265581  4759779
# 1431014   A002 R051 02-03-01 2019-08-01       59 ST  REGULAR  1192103  1832754
# 1431056   A002 R051 02-03-02 2019-08-01       59 ST  REGULAR  6278336  8437921
# ...                      ...        ...         ...      ...      ...      ...
# 1636947  S101A R070 01-03-01 2019-08-01  ST. GEORGE  REGULAR  2066206      226
# 1636989  S101A R070 01-03-02 2019-08-01  ST. GEORGE  REGULAR   511611       31
# 1637031  S101A R070 01-03-03 2019-08-01  ST. GEORGE  REGULAR   154512       40
# 1637073  S101A R070 01-05-00 2019-08-01  ST. GEORGE  REGULAR     1029        0
# 1637115  S101A R070 01-05-01 2019-08-01  ST. GEORGE  REGULAR      678        0
#
# [2471 rows x 6 columns]

# %%
sep1 = df[df.datetime == '2019-09-01']
sep1
# Out:
#                    turnstile   datetime     station     desc  entries    exits
# 1637860   A002 R051 02-00-00 2019-09-01       59 ST  REGULAR  7184008  2433376
# 1637902   A002 R051 02-00-01 2019-09-01       59 ST  REGULAR  6392863  1434893
# 1637944   A002 R051 02-03-00 2019-09-01       59 ST  REGULAR  1280546  4816315
# 1637986   A002 R051 02-03-01 2019-09-01       59 ST  REGULAR  1235317  1885646
# 1638028   A002 R051 02-03-02 2019-09-01       59 ST  REGULAR  6322159  8472943
# ...                      ...        ...         ...      ...      ...      ...
# 1841731  S101A R070 01-03-01 2019-09-01  ST. GEORGE  REGULAR  2089583      235
# 1841773  S101A R070 01-03-02 2019-09-01  ST. GEORGE  REGULAR   529844       33
# 1841815  S101A R070 01-03-03 2019-09-01  ST. GEORGE  REGULAR   171084       42
# 1841857  S101A R070 01-05-00 2019-09-01  ST. GEORGE  REGULAR     1043        0
# 1841899  S101A R070 01-05-01 2019-09-01  ST. GEORGE  REGULAR      688        0
#
# [2481 rows x 6 columns]

# %%
oct1 = df[df.datetime == '2019-10-01']
oct1
# Out:
#                    turnstile   datetime     station     desc  entries    exits
# 1842667   A002 R051 02-00-00 2019-10-01       59 ST  REGULAR  7218487  2445129
# 1842709   A002 R051 02-00-01 2019-10-01       59 ST  REGULAR  6421155  1441810
# 1842751   A002 R051 02-03-00 2019-10-01       59 ST  REGULAR  1293853  4870745
# 1842793   A002 R051 02-03-01 2019-10-01       59 ST  REGULAR  1271880  1937316
# 1842835   A002 R051 02-03-02 2019-10-01       59 ST  REGULAR  6358444  8510632
# ...                      ...        ...         ...      ...      ...      ...
# 2048351  S101A R070 01-03-01 2019-10-01  ST. GEORGE  REGULAR  2112113      235
# 2048393  S101A R070 01-03-02 2019-10-01  ST. GEORGE  REGULAR   547908       34
# 2048435  S101A R070 01-03-03 2019-10-01  ST. GEORGE  REGULAR   187729       45
# 2048477  S101A R070 01-05-00 2019-10-01  ST. GEORGE  REGULAR     1065        0
# 2048519  S101A R070 01-05-01 2019-10-01  ST. GEORGE  REGULAR      698        0
#
# [2457 rows x 6 columns]

# %%
nov1 = df[df.datetime == '2019-11-01']
nov1
# Out:
#                    turnstile   datetime     station     desc  entries    exits
# 2049289   A002 R051 02-00-00 2019-11-01       59 ST  REGULAR  7254773  2458184
# 2049332   A002 R051 02-00-01 2019-11-01       59 ST  REGULAR  6450724  1449023
# 2049375   A002 R051 02-03-00 2019-11-01       59 ST  REGULAR  1307323  4929534
# 2049418   A002 R051 02-03-01 2019-11-01       59 ST  REGULAR  1305700  1991931
# 2049461   A002 R051 02-03-02 2019-11-01       59 ST  REGULAR  6392668  8549660
# ...                      ...        ...         ...      ...      ...      ...
# 2254403  S101A R070 01-03-01 2019-11-01  ST. GEORGE  REGULAR  2137056      247
# 2254445  S101A R070 01-03-02 2019-11-01  ST. GEORGE  REGULAR   567544       49
# 2254487  S101A R070 01-03-03 2019-11-01  ST. GEORGE  REGULAR   204276       46
# 2254529  S101A R070 01-05-00 2019-11-01  ST. GEORGE  REGULAR     1079        0
# 2254571  S101A R070 01-05-01 2019-11-01  ST. GEORGE  REGULAR      707        0
#
# [2480 rows x 6 columns]

# %%
dec1 = df[df.datetime == '2019-12-01']
dec1
# Out:
#                    turnstile   datetime         station     desc   entries  \
# 2259993   A033 R170 02-00-00 2019-12-01  14 ST-UNION SQ  REGULAR    245233
# 2260035   A033 R170 02-00-01 2019-12-01  14 ST-UNION SQ  REGULAR   2382545
# 2260077   A033 R170 02-00-02 2019-12-01  14 ST-UNION SQ  REGULAR  14923585
# 2260119   A033 R170 02-00-03 2019-12-01  14 ST-UNION SQ  REGULAR   7108744
# 2260161   A033 R170 02-00-04 2019-12-01  14 ST-UNION SQ  REGULAR   6373602
# ...                      ...        ...             ...      ...       ...
# 2461018  TRAM2 R469 00-00-01 2019-12-01   RIT-ROOSEVELT  REGULAR   3332717
# 2461060  TRAM2 R469 00-03-00 2019-12-01   RIT-ROOSEVELT  REGULAR    725824
# 2461102  TRAM2 R469 00-03-01 2019-12-01   RIT-ROOSEVELT  REGULAR   3107227
# 2461144  TRAM2 R469 00-05-00 2019-12-01   RIT-ROOSEVELT  REGULAR      3027
# 2461186  TRAM2 R469 00-05-01 2019-12-01   RIT-ROOSEVELT  REGULAR      5554
#
#             exits
# 2259993    751026
# 2260035   2866602
# ...

# %%
df.drop(columns = ['desc'],inplace=True)

# %%
df
# Out:
#                    turnstile            datetime        station  entries  \
# 0         A002 R051 02-00-00 2018-12-29 03:00:00          59 ST  6889287
# 1         A002 R051 02-00-00 2018-12-29 07:00:00          59 ST  6889299
# 2         A002 R051 02-00-00 2018-12-29 11:00:00          59 ST  6889364
# 3         A002 R051 02-00-00 2018-12-29 15:00:00          59 ST  6889605
# 4         A002 R051 02-00-00 2018-12-29 19:00:00          59 ST  6889966
# ...                      ...                 ...            ...      ...
# 2667716  TRAM2 R469 00-05-01 2020-01-03 04:00:00  RIT-ROOSEVELT     5554
# 2667717  TRAM2 R469 00-05-01 2020-01-03 08:00:00  RIT-ROOSEVELT     5554
# 2667718  TRAM2 R469 00-05-01 2020-01-03 12:00:00  RIT-ROOSEVELT     5554
# 2667719  TRAM2 R469 00-05-01 2020-01-03 16:00:00  RIT-ROOSEVELT     5554
# 2667720  TRAM2 R469 00-05-01 2020-01-03 20:00:00  RIT-ROOSEVELT     5554
#
#            exits
# 0        2335920
# 1        2335936
# 2        2336038
# 3        2336101
# ...

# %%
# Out:
#         index            term_id        station linename division       date  \
# 0      201639   A002R05102-00-00          59 ST  NQR456W      BMT 2019-02-01
# 1      201640   A002R05102-00-00          59 ST  NQR456W      BMT 2019-02-01
# 2      201641   A002R05102-00-00          59 ST  NQR456W      BMT 2019-02-01
# 3      201642   A002R05102-00-00          59 ST  NQR456W      BMT 2019-02-01
# 4      201643   A002R05102-00-00          59 ST  NQR456W      BMT 2019-02-01
# ...       ...                ...            ...      ...      ...        ...
# 29166  404510  TRAM2R46900-05-01  RIT-ROOSEVELT        R      RIT 2019-02-01
# 29167  404511  TRAM2R46900-05-01  RIT-ROOSEVELT        R      RIT 2019-02-01
# 29168  404512  TRAM2R46900-05-01  RIT-ROOSEVELT        R      RIT 2019-02-01
# 29169  404513  TRAM2R46900-05-01  RIT-ROOSEVELT        R      RIT 2019-02-01
# 29170  404514  TRAM2R46900-05-01  RIT-ROOSEVELT        R      RIT 2019-02-01
#
#            time     desc  entries  \
# ...

# %%
merge_try = pd.merge(feb,mar, on = 'term_id')

# %%
merge_try['daily'] = (merge_try.entries_y)-(merge_try.entries_x)

# %%
merge_try.groupby(['station_x','term_id']).head()
# Out:
#         index_x            term_id      station_x linename_x division_x  \
# 0        201639   A002R05102-00-00          59 ST    NQR456W        BMT
# 1        201639   A002R05102-00-00          59 ST    NQR456W        BMT
# 2        201639   A002R05102-00-00          59 ST    NQR456W        BMT
# 3        201639   A002R05102-00-00          59 ST    NQR456W        BMT
# 4        201639   A002R05102-00-00          59 ST    NQR456W        BMT
# ...         ...                ...            ...        ...        ...
# 173113   404509  TRAM2R46900-05-01  RIT-ROOSEVELT          R        RIT
# 173114   404509  TRAM2R46900-05-01  RIT-ROOSEVELT          R        RIT
# 173115   404509  TRAM2R46900-05-01  RIT-ROOSEVELT          R        RIT
# 173116   404509  TRAM2R46900-05-01  RIT-ROOSEVELT          R        RIT
# 173117   404509  TRAM2R46900-05-01  RIT-ROOSEVELT          R        RIT
#
#            date_x    time_x   desc_x  entries_x  \
# 0      2019-02-01  03:00:00  REGULAR    6929470
# ...

# %%
apr.head()
# Out:
#     index           term_id station linename division       date      time  \
# 0  607716  A002R05102-00-00   59 ST  NQR456W      BMT 2019-04-01  00:00:00
# 1  607717  A002R05102-00-00   59 ST  NQR456W      BMT 2019-04-01  04:00:00
# 2  607718  A002R05102-00-00   59 ST  NQR456W      BMT 2019-04-01  08:00:00
# 3  607719  A002R05102-00-00   59 ST  NQR456W      BMT 2019-04-01  12:00:00
# 4  607720  A002R05102-00-00   59 ST  NQR456W      BMT 2019-04-01  16:00:00
#
#       desc  entries  \
# 0  REGULAR  7000528
# 1  REGULAR  7000539
# 2  REGULAR  7000583
# 3  REGULAR  7000744
# 4  REGULAR  7001078
#
#    exits
# 0                                            2374095
# 1                                            2374095
# 2                                            2374207
# 3                                            2374438
# 4                                            2374491

# %%
jan_week1 = jan.groupby(['term_id','date'])

# %%
jan_week1.head(50)
# Out:
#          index            term_id        station linename division       date  \
# 0           18   A002R05102-00-00          59 ST  NQR456W      BMT 2019-01-01
# 1           19   A002R05102-00-00          59 ST  NQR456W      BMT 2019-01-01
# 2           20   A002R05102-00-00          59 ST  NQR456W      BMT 2019-01-01
# 3           21   A002R05102-00-00          59 ST  NQR456W      BMT 2019-01-01
# 4           22   A002R05102-00-00          59 ST  NQR456W      BMT 2019-01-01
# ...        ...                ...            ...      ...      ...        ...
# 115400  201598  TRAM2R46900-05-01  RIT-ROOSEVELT        R      RIT 2019-01-04
# 115401  201599  TRAM2R46900-05-01  RIT-ROOSEVELT        R      RIT 2019-01-04
# 115402  201600  TRAM2R46900-05-01  RIT-ROOSEVELT        R      RIT 2019-01-04
# 115403  201601  TRAM2R46900-05-01  RIT-ROOSEVELT        R      RIT 2019-01-04
# 115404  201602  TRAM2R46900-05-01  RIT-ROOSEVELT        R      RIT 2019-01-04
#
# ...

# %%
pd.to_datetime(df2.time)
# Out:
# 0         2021-03-27 03:00:00
# 1         2021-03-27 07:00:00
# 2         2021-03-27 11:00:00
# 3         2021-03-27 15:00:00
# 4         2021-03-27 19:00:00
#                   ...
# 2667716   2021-03-27 04:00:00
# 2667717   2021-03-27 08:00:00
# 2667718   2021-03-27 12:00:00
# 2667719   2021-03-27 16:00:00
# 2667720   2021-03-27 20:00:00
# Name: time, Length: 2667721, dtype: datetime64[ns]

# %%
df2.time = pd.to_datetime(df2.time)
# Out:
# /Users/michaelharnett/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2667721 entries, 0 to 2667720
# Data columns (total 9 columns):
#  #   Column                                                                Dtype
# ---  ------                                                                -----
#  0   term_id                                                               object
#  1   station                                                               object
#  2   linename                                                              object
#  3   division                                                              object
#  4   date                                                                  datetime64[ns]
#  5   time                                                                  datetime64[ns]
#  6   desc                                                                  object
#  7   entries                                                               int64
# ...

# %%
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/29/2018  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/29/2018  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/29/2018  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/29/2018  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/29/2018  19:00:00
#
#       desc  entries  \
# 0  REGULAR  6889287
# 1  REGULAR  6889299
# 2  REGULAR  6889364
# 3  REGULAR  6889605
# 4  REGULAR  6889966
#
#    exits                                                                 \
# 0                                            2335920
# 1                                            2335936
# 2                                            2336038
# 3                                            2336101
# 4                                            2336173
#
#             term_id
# 0  A002R05102-00-00
# ...

# %%
df2.head()
# Out:
#             term_id station linename division       date                time  \
# 0  A002R05102-00-00   59 ST  NQR456W      BMT 2018-12-29 2021-03-27 03:00:00
# 1  A002R05102-00-00   59 ST  NQR456W      BMT 2018-12-29 2021-03-27 07:00:00
# 2  A002R05102-00-00   59 ST  NQR456W      BMT 2018-12-29 2021-03-27 11:00:00
# 3  A002R05102-00-00   59 ST  NQR456W      BMT 2018-12-29 2021-03-27 15:00:00
# 4  A002R05102-00-00   59 ST  NQR456W      BMT 2018-12-29 2021-03-27 19:00:00
#
#       desc  entries  \
# 0  REGULAR  6889287
# 1  REGULAR  6889299
# 2  REGULAR  6889364
# 3  REGULAR  6889605
# 4  REGULAR  6889966
#
#    exits
# 0                                            2335920
# 1                                            2335936
# 2                                            2336038
# 3                                            2336101
# 4                                            2336173

# %%
jan.term_id.isunique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-162-359e16b38796> in <module>
# ----> 1 jan.term_id.isunique()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'isunique'

# %%
df.turnstile.nunique()
# Out:
# 4993

# %%
jan1.turnstile.nunique()
# Out:
# 1771

# %%
feb1.turnstile.nunique()
# Out:
# 1773

# %%
mar1.turnstile.nunique()
# Out:
# 1793

# %%
jan1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1771 entries, 0 to 1770
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      1771 non-null   int64
#  1   turnstile  1771 non-null   object
#  2   datetime   1771 non-null   datetime64[ns]
#  3   station    1771 non-null   object
#  4   entries    1771 non-null   int64
#  5   exits      1771 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 83.1+ KB

# %%
feb_en = feb1['entries']
feb_en
# Out:
# 0        2090072
# 1        1866376
# 2       14270131
# 3        6172182
# 4        5076576
#           ...
# 1768     2918642
# 1769      641235
# 1770     3021398
# 1771        2850
# 1772        5554
# Name: entries, Length: 1773, dtype: int64

# %%
merge_try2 = pd.merge(jan1,feb1[['turnstile','entries','exits']], on='turnstile')

# %%
merge_try2
# Out:
#        index            turnstile   datetime         station  entries_x  \
# 0       4748   A033 R170 02-00-00 2019-01-01  14 ST-UNION SQ    2058504
# 1       4790   A033 R170 02-00-01 2019-01-01  14 ST-UNION SQ    1810289
# 2       4832   A033 R170 02-00-02 2019-01-01  14 ST-UNION SQ   14202557
# 3       4874   A033 R170 02-00-03 2019-01-01  14 ST-UNION SQ    6077136
# 4       4916   A033 R170 02-00-04 2019-01-01  14 ST-UNION SQ    4939956
# ...      ...                  ...        ...             ...        ...
# 1743  201401  TRAM2 R469 00-00-01 2019-01-01   RIT-ROOSEVELT    2876975
# 1744  201445  TRAM2 R469 00-03-00 2019-01-01   RIT-ROOSEVELT     635516
# 1745  201489  TRAM2 R469 00-03-01 2019-01-01   RIT-ROOSEVELT    3015572
# 1746  201533  TRAM2 R469 00-05-00 2019-01-01   RIT-ROOSEVELT       2838
# 1747  201577  TRAM2 R469 00-05-01 2019-01-01   RIT-ROOSEVELT       5554
#
#        exits_x  entries_y   exits_y
# 0      5184532    2090072   5262018
# ...

# %%
merge_try2
# Out:
#        index            turnstile   datetime         station  entries_x  \
# 0       4748   A033 R170 02-00-00 2019-01-01  14 ST-UNION SQ    2058504
# 1       4790   A033 R170 02-00-01 2019-01-01  14 ST-UNION SQ    1810289
# 2       4832   A033 R170 02-00-02 2019-01-01  14 ST-UNION SQ   14202557
# 3       4874   A033 R170 02-00-03 2019-01-01  14 ST-UNION SQ    6077136
# 4       4916   A033 R170 02-00-04 2019-01-01  14 ST-UNION SQ    4939956
# ...      ...                  ...        ...             ...        ...
# 1743  201401  TRAM2 R469 00-00-01 2019-01-01   RIT-ROOSEVELT    2876975
# 1744  201445  TRAM2 R469 00-03-00 2019-01-01   RIT-ROOSEVELT     635516
# 1745  201489  TRAM2 R469 00-03-01 2019-01-01   RIT-ROOSEVELT    3015572
# 1746  201533  TRAM2 R469 00-05-00 2019-01-01   RIT-ROOSEVELT       2838
# 1747  201577  TRAM2 R469 00-05-01 2019-01-01   RIT-ROOSEVELT       5554
#
#          exits  feb_entries
# 0      5184532      2090072
# 1      2188156      1866376
# ...

# %%
merge_try2.feb_entries = abs(merge_try2.feb_entries - merge_try2.entries_x)

# %%
merge_try2
# Out:
#        index            turnstile   datetime         station  entries_x  \
# 0       4748   A033 R170 02-00-00 2019-01-01  14 ST-UNION SQ    2058504
# 1       4790   A033 R170 02-00-01 2019-01-01  14 ST-UNION SQ    1810289
# 2       4832   A033 R170 02-00-02 2019-01-01  14 ST-UNION SQ   14202557
# 3       4874   A033 R170 02-00-03 2019-01-01  14 ST-UNION SQ    6077136
# 4       4916   A033 R170 02-00-04 2019-01-01  14 ST-UNION SQ    4939956
# ...      ...                  ...        ...             ...        ...
# 1743  201401  TRAM2 R469 00-00-01 2019-01-01   RIT-ROOSEVELT    2876975
# 1744  201445  TRAM2 R469 00-03-00 2019-01-01   RIT-ROOSEVELT     635516
# 1745  201489  TRAM2 R469 00-03-01 2019-01-01   RIT-ROOSEVELT    3015572
# 1746  201533  TRAM2 R469 00-05-00 2019-01-01   RIT-ROOSEVELT       2838
# 1747  201577  TRAM2 R469 00-05-01 2019-01-01   RIT-ROOSEVELT       5554
#
#          exits  feb_entries
# 0      5184532      2026936
# 1      2188156      1754202
# ...

# %%
merge_try2.feb_entries.describe()
# Out:
# count    1.748000e+03
# mean     3.469965e+07
# std      1.833722e+08
# min      0.000000e+00
# 25%      4.587750e+05
# 50%      2.262249e+06
# 75%      6.466735e+06
# max      2.552686e+09
# Name: feb_entries, dtype: float64

# %%
merge=merge_try2

# %%
merge.rename(columns = {'entries_x':'starting_entries'},inplace=True)

# %%
merge
# Out:
#        index            turnstile   datetime         station  \
# 0       4748   A033 R170 02-00-00 2019-01-01  14 ST-UNION SQ
# 1       4790   A033 R170 02-00-01 2019-01-01  14 ST-UNION SQ
# 2       4832   A033 R170 02-00-02 2019-01-01  14 ST-UNION SQ
# 3       4874   A033 R170 02-00-03 2019-01-01  14 ST-UNION SQ
# 4       4916   A033 R170 02-00-04 2019-01-01  14 ST-UNION SQ
# ...      ...                  ...        ...             ...
# 1743  201401  TRAM2 R469 00-00-01 2019-01-01   RIT-ROOSEVELT
# 1744  201445  TRAM2 R469 00-03-00 2019-01-01   RIT-ROOSEVELT
# 1745  201489  TRAM2 R469 00-03-01 2019-01-01   RIT-ROOSEVELT
# 1746  201533  TRAM2 R469 00-05-00 2019-01-01   RIT-ROOSEVELT
# 1747  201577  TRAM2 R469 00-05-01 2019-01-01   RIT-ROOSEVELT
#
#       starting_entries     exits  feb_entries
# 0              2058504   5184532      2026936
# 1              1810289   2188156      1754202
# 2             14202557  13711236     14134983
# ...

# %%
# Out:
#        index            turnstile   datetime         station  \
# 0       4748   A033 R170 02-00-00 2019-01-01  14 ST-UNION SQ
# 1       4790   A033 R170 02-00-01 2019-01-01  14 ST-UNION SQ
# 2       4832   A033 R170 02-00-02 2019-01-01  14 ST-UNION SQ
# 3       4874   A033 R170 02-00-03 2019-01-01  14 ST-UNION SQ
# 4       4916   A033 R170 02-00-04 2019-01-01  14 ST-UNION SQ
# ...      ...                  ...        ...             ...
# 1743  201401  TRAM2 R469 00-00-01 2019-01-01   RIT-ROOSEVELT
# 1744  201445  TRAM2 R469 00-03-00 2019-01-01   RIT-ROOSEVELT
# 1745  201489  TRAM2 R469 00-03-01 2019-01-01   RIT-ROOSEVELT
# 1746  201533  TRAM2 R469 00-05-00 2019-01-01   RIT-ROOSEVELT
# 1747  201577  TRAM2 R469 00-05-01 2019-01-01   RIT-ROOSEVELT
#
#       starting_entries     exits  feb_entries
# 0              2058504   5184532      2026936
# 1              1810289   2188156      1754202
# 2             14202557  13711236     14134983
# ...

# %%
merge = pd.merge(jan1,feb1[['turnstile','entries','exits']], on='turnstile')

# %%
merge = pd.merge(merge, mar1[['turnstile', 'entries', 'exits']], on = 'turnstile', suffixes = ['_march','_march']
# Out:
#   File "<ipython-input-268-586128b8d465>", line 1
#     merge = pd.merge(merge, mar1[['turnstile', 'entries', 'exits']], on = 'turnstile', suffixes = ['_march','_march']
#                                                                                                                      ^
# SyntaxError: unexpected EOF while parsing

# %%
merge.rename(columns = {'entries_x': 'starting_entries',
                        'exits_x': 'starting_exits',
                        'entries_y': 'feb_entries',
                        'exits_y': 'feb_exits'}, inplace = True)

# %%
merge = pd.merge(merge, mar1[mar1])
# Out:
#        index            turnstile   datetime         station  \
# 0       4748   A033 R170 02-00-00 2019-01-01  14 ST-UNION SQ
# 1       4790   A033 R170 02-00-01 2019-01-01  14 ST-UNION SQ
# 2       4832   A033 R170 02-00-02 2019-01-01  14 ST-UNION SQ
# 3       4874   A033 R170 02-00-03 2019-01-01  14 ST-UNION SQ
# 4       4916   A033 R170 02-00-04 2019-01-01  14 ST-UNION SQ
# ...      ...                  ...        ...             ...
# 1743  201401  TRAM2 R469 00-00-01 2019-01-01   RIT-ROOSEVELT
# 1744  201445  TRAM2 R469 00-03-00 2019-01-01   RIT-ROOSEVELT
# 1745  201489  TRAM2 R469 00-03-01 2019-01-01   RIT-ROOSEVELT
# 1746  201533  TRAM2 R469 00-05-00 2019-01-01   RIT-ROOSEVELT
# 1747  201577  TRAM2 R469 00-05-01 2019-01-01   RIT-ROOSEVELT
#
#       starting_entries  starting_exits  feb_entries  feb_exits
# 0              2058504         5184532      2090072    5262018
# 1              1810289         2188156      1866376    2248359
# ...

# %%
merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1748 entries, 0 to 1747
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   index                         1748 non-null   int64
#  1   turnstile                     1748 non-null   object
#  2   datetime                      1748 non-null   datetime64[ns]
#  3   station                       1748 non-null   object
#  4   starting_entries              1748 non-null   int64
#  5   starting_exits                1748 non-null   int64
#  6   feb_entries                   1748 non-null   int64
#  7   feb_exits                     1748 non-null   int64
#  8   (march_entries, march_exits)  1748 non-null   object
# dtypes: datetime64[ns](1), int64(5), object(3)
# memory usage: 136.6+ KB

# %%
merge.drop(columns=''(march_entries, march_exits)')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-273-112adcb86ab7> in <module>
# ----> 1 merge.drop(columns='(march_entries, march_exits)')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
merge.drop(columns=['march_entries, march_exits'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-277-5e609d688a2b> in <module>
# ----> 1 merge.drop(columns=['march_entries, march_exits'],inplace=True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
merge = merge_try2

# %%
merge.rename(columns = {'entries_x': 'starting_entries',
                       'exits_x': 'starting_exits',
                       'entries_y': 'entries_feb',
                       'exits_y': 'exits_feb'})
# Out:
#        index            turnstile   datetime         station  \
# 0       4748   A033 R170 02-00-00 2019-01-01  14 ST-UNION SQ
# 1       4790   A033 R170 02-00-01 2019-01-01  14 ST-UNION SQ
# 2       4832   A033 R170 02-00-02 2019-01-01  14 ST-UNION SQ
# 3       4874   A033 R170 02-00-03 2019-01-01  14 ST-UNION SQ
# 4       4916   A033 R170 02-00-04 2019-01-01  14 ST-UNION SQ
# ...      ...                  ...        ...             ...
# 1743  201401  TRAM2 R469 00-00-01 2019-01-01   RIT-ROOSEVELT
# 1744  201445  TRAM2 R469 00-03-00 2019-01-01   RIT-ROOSEVELT
# 1745  201489  TRAM2 R469 00-03-01 2019-01-01   RIT-ROOSEVELT
# 1746  201533  TRAM2 R469 00-05-00 2019-01-01   RIT-ROOSEVELT
# 1747  201577  TRAM2 R469 00-05-01 2019-01-01   RIT-ROOSEVELT
#
#       starting_entries  starting_exits  entries_feb  entries_feb
# 0              2058504         5184532      2090072      5262018
# 1              1810289         2188156      1866376      2248359
# ...

# %%
merge2 = pd.merge(merge,mar1[['turnstile','entries','exits']],on='turnstile',suffixes = '_march_entries','_march')
# Out:
#   File "<ipython-input-292-a911a1ceb090>", line 1
#     merge2 = pd.merge(merge,mar1[['turnstile','entries','exits']],on='turnstile',suffixes = '_march_entries','_march')
#                                                                                                              ^
# SyntaxError: positional argument follows keyword argument

# %%
merge2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-293-6630ba4922bc> in <module>
# ----> 1 merge2
#
# NameError: name 'merge2' is not defined

# %%
df_ultimate.rename(columns ={
    'entries_x': 'starting_entreis',
    'exits_x': 'starting_exits',
    'entries_y': 'february_entreis',
    'exits_y': 'february_exits',
    'entries': 'march_entries',
    'exits': 'march_exits'},inplace=True)

# %%
df_ultimate = pd.merge(df_ultimate, mar1[['turnstile', 'entries', 'exits']],
                       on ='turnstile')

# %%
df_ultimate
# Out:
#        index            turnstile   datetime         station  entries_x  \
# 0       4748   A033 R170 02-00-00 2019-01-01  14 ST-UNION SQ    2058504
# 1       4790   A033 R170 02-00-01 2019-01-01  14 ST-UNION SQ    1810289
# 2       4832   A033 R170 02-00-02 2019-01-01  14 ST-UNION SQ   14202557
# 3       4874   A033 R170 02-00-03 2019-01-01  14 ST-UNION SQ    6077136
# 4       4916   A033 R170 02-00-04 2019-01-01  14 ST-UNION SQ    4939956
# ...      ...                  ...        ...             ...        ...
# 1723  201401  TRAM2 R469 00-00-01 2019-01-01   RIT-ROOSEVELT    2876975
# 1724  201445  TRAM2 R469 00-03-00 2019-01-01   RIT-ROOSEVELT     635516
# 1725  201489  TRAM2 R469 00-03-01 2019-01-01   RIT-ROOSEVELT    3015572
# 1726  201533  TRAM2 R469 00-05-00 2019-01-01   RIT-ROOSEVELT       2838
# 1727  201577  TRAM2 R469 00-05-01 2019-01-01   RIT-ROOSEVELT       5554
#
#        exits_x  entries_y   exits_y   entries     exits
# ...

# %%
df_ultimate
# Out:
#        index            turnstile   datetime         station  \
# 0       4748   A033 R170 02-00-00 2019-01-01  14 ST-UNION SQ
# 1       4790   A033 R170 02-00-01 2019-01-01  14 ST-UNION SQ
# 2       4832   A033 R170 02-00-02 2019-01-01  14 ST-UNION SQ
# 3       4874   A033 R170 02-00-03 2019-01-01  14 ST-UNION SQ
# 4       4916   A033 R170 02-00-04 2019-01-01  14 ST-UNION SQ
# ...      ...                  ...        ...             ...
# 1723  201401  TRAM2 R469 00-00-01 2019-01-01   RIT-ROOSEVELT
# 1724  201445  TRAM2 R469 00-03-00 2019-01-01   RIT-ROOSEVELT
# 1725  201489  TRAM2 R469 00-03-01 2019-01-01   RIT-ROOSEVELT
# 1726  201533  TRAM2 R469 00-05-00 2019-01-01   RIT-ROOSEVELT
# 1727  201577  TRAM2 R469 00-05-01 2019-01-01   RIT-ROOSEVELT
#
#       starting_entreis  starting_exits  february_entreis  february_exits  \
# 0              2058504         5184532           2090072         5262018
# 1              1810289         2188156           1866376         2248359
# ...

# %%
df
# Out:
#                    turnstile            datetime        station  entries  \
# 0         A002 R051 02-00-00 2018-12-29 03:00:00          59 ST  6889287
# 1         A002 R051 02-00-00 2018-12-29 07:00:00          59 ST  6889299
# 2         A002 R051 02-00-00 2018-12-29 11:00:00          59 ST  6889364
# 3         A002 R051 02-00-00 2018-12-29 15:00:00          59 ST  6889605
# 4         A002 R051 02-00-00 2018-12-29 19:00:00          59 ST  6889966
# ...                      ...                 ...            ...      ...
# 2667716  TRAM2 R469 00-05-01 2020-01-03 04:00:00  RIT-ROOSEVELT     5554
# 2667717  TRAM2 R469 00-05-01 2020-01-03 08:00:00  RIT-ROOSEVELT     5554
# 2667718  TRAM2 R469 00-05-01 2020-01-03 12:00:00  RIT-ROOSEVELT     5554
# 2667719  TRAM2 R469 00-05-01 2020-01-03 16:00:00  RIT-ROOSEVELT     5554
# 2667720  TRAM2 R469 00-05-01 2020-01-03 20:00:00  RIT-ROOSEVELT     5554
#
#            exits
# 0        2335920
# 1        2335936
# 2        2336038
# 3        2336101
# ...

# %%
jan1
# Out:
#        index            turnstile   datetime         station   entries  \
# 0       4748   A033 R170 02-00-00 2019-01-01  14 ST-UNION SQ   2058504
# 1       4790   A033 R170 02-00-01 2019-01-01  14 ST-UNION SQ   1810289
# 2       4832   A033 R170 02-00-02 2019-01-01  14 ST-UNION SQ  14202557
# 3       4874   A033 R170 02-00-03 2019-01-01  14 ST-UNION SQ   6077136
# 4       4916   A033 R170 02-00-04 2019-01-01  14 ST-UNION SQ   4939956
# ...      ...                  ...        ...             ...       ...
# 1766  201401  TRAM2 R469 00-00-01 2019-01-01   RIT-ROOSEVELT   2876975
# 1767  201445  TRAM2 R469 00-03-00 2019-01-01   RIT-ROOSEVELT    635516
# 1768  201489  TRAM2 R469 00-03-01 2019-01-01   RIT-ROOSEVELT   3015572
# 1769  201533  TRAM2 R469 00-05-00 2019-01-01   RIT-ROOSEVELT      2838
# 1770  201577  TRAM2 R469 00-05-01 2019-01-01   RIT-ROOSEVELT      5554
#
#          exits
# 0      5184532
# 1      2188156
# 2     13711236
# 3      7085828
# 4      3757483
# ...        ...
# ...

# %%
df_ultimate
# Out:
#        index            turnstile   datetime         station  \
# 0       4748   A033 R170 02-00-00 2019-01-01  14 ST-UNION SQ
# 1       4790   A033 R170 02-00-01 2019-01-01  14 ST-UNION SQ
# 2       4832   A033 R170 02-00-02 2019-01-01  14 ST-UNION SQ
# 3       4874   A033 R170 02-00-03 2019-01-01  14 ST-UNION SQ
# 4       4916   A033 R170 02-00-04 2019-01-01  14 ST-UNION SQ
# ...      ...                  ...        ...             ...
# 1723  201401  TRAM2 R469 00-00-01 2019-01-01   RIT-ROOSEVELT
# 1724  201445  TRAM2 R469 00-03-00 2019-01-01   RIT-ROOSEVELT
# 1725  201489  TRAM2 R469 00-03-01 2019-01-01   RIT-ROOSEVELT
# 1726  201533  TRAM2 R469 00-05-00 2019-01-01   RIT-ROOSEVELT
# 1727  201577  TRAM2 R469 00-05-01 2019-01-01   RIT-ROOSEVELT
#
#       starting_entreis  starting_exits  february_entries  february_exits  \
# 0              2058504         5184532           2090072         5262018
# 1              1810289         2188156           1866376         2248359
# ...

# %%
df_ultimate['feb_totals'] = df_ultimate.february_entries - df_ultimate.starting_entries
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-320-1a49ecd561b3> in <module>
# ----> 1 df_ultimate['feb_totals'] = df_ultimate.february_entries - df_ultimate.starting_entries
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'february_entries'

# %%
df_ultimate.rename(columns = {'Feb_Entries': 'feb_entries'},inplace = True)

# %%
df_ultimate['Feb_Totals_'] = df_ultimate.february_entries - df_ultimate.starting_entries

# %%
df_ultimate
# Out:
#        index            turnstile   datetime         station  \
# 0       4748   A033 R170 02-00-00 2019-01-01  14 ST-UNION SQ
# 1       4790   A033 R170 02-00-01 2019-01-01  14 ST-UNION SQ
# 2       4832   A033 R170 02-00-02 2019-01-01  14 ST-UNION SQ
# 3       4874   A033 R170 02-00-03 2019-01-01  14 ST-UNION SQ
# 4       4916   A033 R170 02-00-04 2019-01-01  14 ST-UNION SQ
# ...      ...                  ...        ...             ...
# 1723  201401  TRAM2 R469 00-00-01 2019-01-01   RIT-ROOSEVELT
# 1724  201445  TRAM2 R469 00-03-00 2019-01-01   RIT-ROOSEVELT
# 1725  201489  TRAM2 R469 00-03-01 2019-01-01   RIT-ROOSEVELT
# 1726  201533  TRAM2 R469 00-05-00 2019-01-01   RIT-ROOSEVELT
# 1727  201577  TRAM2 R469 00-05-01 2019-01-01   RIT-ROOSEVELT
#
#       starting_entries  starting_exits  february_exits  march_entries  \
# 0              2058504         5184532         5262018        2117780
# 1              1810289         2188156         2248359        1916183
# ...

# %%
df
# Out:
#                    turnstile            datetime        station  entries  \
# 0         A002 R051 02-00-00 2018-12-29 03:00:00          59 ST  6889287
# 1         A002 R051 02-00-00 2018-12-29 07:00:00          59 ST  6889299
# 2         A002 R051 02-00-00 2018-12-29 11:00:00          59 ST  6889364
# 3         A002 R051 02-00-00 2018-12-29 15:00:00          59 ST  6889605
# 4         A002 R051 02-00-00 2018-12-29 19:00:00          59 ST  6889966
# ...                      ...                 ...            ...      ...
# 2667716  TRAM2 R469 00-05-01 2020-01-03 04:00:00  RIT-ROOSEVELT     5554
# 2667717  TRAM2 R469 00-05-01 2020-01-03 08:00:00  RIT-ROOSEVELT     5554
# 2667718  TRAM2 R469 00-05-01 2020-01-03 12:00:00  RIT-ROOSEVELT     5554
# 2667719  TRAM2 R469 00-05-01 2020-01-03 16:00:00  RIT-ROOSEVELT     5554
# 2667720  TRAM2 R469 00-05-01 2020-01-03 20:00:00  RIT-ROOSEVELT     5554
#
#            exits  feb_entries  feb_exits
# 0        2335920    2086212.0        0.0
# ...

# %%
df_ultimate.drop(columns = 'february_exits',inplace=True)

# %%
cols.insert(7, cols.pop(cols.index('feb_exits')))

# %%
df_ultimate = df_ultimate[cols]

# %%
df_ultimate
# Out:
#        index            turnstile   datetime         station  \
# 0       4748   A033 R170 02-00-00 2019-01-01  14 ST-UNION SQ
# 1       4790   A033 R170 02-00-01 2019-01-01  14 ST-UNION SQ
# 2       4832   A033 R170 02-00-02 2019-01-01  14 ST-UNION SQ
# 3       4874   A033 R170 02-00-03 2019-01-01  14 ST-UNION SQ
# 4       4916   A033 R170 02-00-04 2019-01-01  14 ST-UNION SQ
# ...      ...                  ...        ...             ...
# 1723  201401  TRAM2 R469 00-00-01 2019-01-01   RIT-ROOSEVELT
# 1724  201445  TRAM2 R469 00-03-00 2019-01-01   RIT-ROOSEVELT
# 1725  201489  TRAM2 R469 00-03-01 2019-01-01   RIT-ROOSEVELT
# 1726  201533  TRAM2 R469 00-05-00 2019-01-01   RIT-ROOSEVELT
# 1727  201577  TRAM2 R469 00-05-01 2019-01-01   RIT-ROOSEVELT
#
#       starting_entries  starting_exits  jan_entries  jan_exits  march_entries  \
# 0              2058504         5184532        31568      77486        2117780
# ...

# %%
df_ultimate['feb_exits'] = df_ultimate.february_exits - df_ultimate.starting_exits
# Out:
# <ipython-input-356-15f4597d4b8b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ultimate['feb_exits'] = df_ultimate.february_exits - df_ultimate.starting_exits

# %%
df_ultimate.rename(columns={
    'feb_entries': 'jan_entries',
    'feb_exits': 'jan_exits'
},inplace=True)

# %%
df_ultimate['feb_entries'] = df_ultimate.march_entries - df_ultimate.jan_entries

# %%
df_ultimate['feb_exits'] = df_ultimate.march_exits - df_ultimate.jan_exits

# %%
mar1.iloc[0,'turnstile']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     701             try:
# --> 702                 self._validate_key(k, i)
#     703             except ValueError as err:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1368         else:
# -> 1369             raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#    1370
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-461-2ca22b1c4768> in <module>
# ...

# %%
df_ultimate.drop(columns = '',inplace=True)

# %%
df_ultimate
# Out:
#        index            turnstile   datetime         station  \
# 0       4748   A033 R170 02-00-00 2019-01-01  14 ST-UNION SQ
# 1       4790   A033 R170 02-00-01 2019-01-01  14 ST-UNION SQ
# 2       4832   A033 R170 02-00-02 2019-01-01  14 ST-UNION SQ
# 3       4874   A033 R170 02-00-03 2019-01-01  14 ST-UNION SQ
# 4       4916   A033 R170 02-00-04 2019-01-01  14 ST-UNION SQ
# ...      ...                  ...        ...             ...
# 1723  201401  TRAM2 R469 00-00-01 2019-01-01   RIT-ROOSEVELT
# 1724  201445  TRAM2 R469 00-03-00 2019-01-01   RIT-ROOSEVELT
# 1725  201489  TRAM2 R469 00-03-01 2019-01-01   RIT-ROOSEVELT
# 1726  201533  TRAM2 R469 00-05-00 2019-01-01   RIT-ROOSEVELT
# 1727  201577  TRAM2 R469 00-05-01 2019-01-01   RIT-ROOSEVELT
#
#       starting_entries  starting_exits  jan_entries  jan_exits  march_entries  \
# 0              2058504         5184532        31568      77486        2117780
# ...

# %%
jan1
# Out:
#        index            turnstile   datetime         station   entries  \
# 0       4748   A033 R170 02-00-00 2019-01-01  14 ST-UNION SQ   2058504
# 1       4790   A033 R170 02-00-01 2019-01-01  14 ST-UNION SQ   1810289
# 2       4832   A033 R170 02-00-02 2019-01-01  14 ST-UNION SQ  14202557
# 3       4874   A033 R170 02-00-03 2019-01-01  14 ST-UNION SQ   6077136
# 4       4916   A033 R170 02-00-04 2019-01-01  14 ST-UNION SQ   4939956
# ...      ...                  ...        ...             ...       ...
# 1766  201401  TRAM2 R469 00-00-01 2019-01-01   RIT-ROOSEVELT   2876975
# 1767  201445  TRAM2 R469 00-03-00 2019-01-01   RIT-ROOSEVELT    635516
# 1768  201489  TRAM2 R469 00-03-01 2019-01-01   RIT-ROOSEVELT   3015572
# 1769  201533  TRAM2 R469 00-05-00 2019-01-01   RIT-ROOSEVELT      2838
# 1770  201577  TRAM2 R469 00-05-01 2019-01-01   RIT-ROOSEVELT      5554
#
#          exits
# 0      5184532
# 1      2188156
# 2     13711236
# 3      7085828
# 4      3757483
# ...        ...
# ...

# %%
feb1
# Out:
#        index            turnstile   datetime         station   entries  \
# 0     206157   A033 R170 02-00-00 2019-02-01  14 ST-UNION SQ   2090072
# 1     206200   A033 R170 02-00-01 2019-02-01  14 ST-UNION SQ   1866376
# 2     206243   A033 R170 02-00-02 2019-02-01  14 ST-UNION SQ  14270131
# 3     206286   A033 R170 02-00-03 2019-02-01  14 ST-UNION SQ   6172182
# 4     206329   A033 R170 02-00-04 2019-02-01  14 ST-UNION SQ   5076576
# ...      ...                  ...        ...             ...       ...
# 1768  404341  TRAM2 R469 00-00-01 2019-02-01   RIT-ROOSEVELT   2918642
# 1769  404383  TRAM2 R469 00-03-00 2019-02-01   RIT-ROOSEVELT    641235
# 1770  404425  TRAM2 R469 00-03-01 2019-02-01   RIT-ROOSEVELT   3021398
# 1771  404467  TRAM2 R469 00-05-00 2019-02-01   RIT-ROOSEVELT      2850
# 1772  404509  TRAM2 R469 00-05-01 2019-02-01   RIT-ROOSEVELT      5554
#
#          exits
# 0      5262018
# 1      2248359
# 2     13784467
# 3      7206372
# 4      3863436
# ...        ...
# ...

# %%
tryz = feb1.entries - jan1.entries

# %%
tryz
# Out:
# 0         31568.0
# 1         56087.0
# 2         67574.0
# 3         95046.0
# 4        136620.0
#           ...
# 1768     -96930.0
# 1769     638397.0
# 1770    3015844.0
# 1771          NaN
# 1772          NaN
# Name: entries, Length: 1773, dtype: float64

# %%
tryz = apr1.entries - mar1.entries

# %%
tryz
# Out:
# 409411   NaN
# 409453   NaN
# 409495   NaN
# 409537   NaN
# 409579   NaN
#           ..
# 809756   NaN
# 809798   NaN
# 809840   NaN
# 809882   NaN
# 809924   NaN
# Name: entries, Length: 4268, dtype: float64

# %%
df_ulta = pd.merge(df_ultimate,feb1[['turnstile','entries','exits']],on='turnstile')

# %%
mar
# Out:
#         index            turnstile            datetime        station  \
# 0      404545   A002 R051 02-00-00 2019-02-28 03:00:00          59 ST
# 1      404546   A002 R051 02-00-00 2019-02-28 07:00:00          59 ST
# 2      404547   A002 R051 02-00-00 2019-02-28 11:00:00          59 ST
# 3      404548   A002 R051 02-00-00 2019-02-28 15:00:00          59 ST
# 4      404549   A002 R051 02-00-00 2019-02-28 19:00:00          59 ST
# ...       ...                  ...                 ...            ...
# 55934  607699  TRAM2 R469 00-05-01 2019-03-01 04:00:00  RIT-ROOSEVELT
# 55935  607700  TRAM2 R469 00-05-01 2019-03-01 08:00:00  RIT-ROOSEVELT
# 55936  607701  TRAM2 R469 00-05-01 2019-03-01 12:00:00  RIT-ROOSEVELT
# 55937  607702  TRAM2 R469 00-05-01 2019-03-01 16:00:00  RIT-ROOSEVELT
# 55938  607703  TRAM2 R469 00-05-01 2019-03-01 20:00:00  RIT-ROOSEVELT
#
#           desc  entries    exits  group_nums
# 0      REGULAR  6960690  2361132           0
# ...

# %%
df_ulta['feb_entries'] = df_ulta.march_entries - df_ulta.entries

# %%
df_ulta['feb_exits'] = df_ulta.march_exits - df_ulta.exits

# %%
df_ulta.drop(columns = ['entries','exits'],inplace=True)

# %%
df_ulta = pd.merge(df_ulta, apr1[['turnstile','entries','exits']],on='turnstile')

# %%
df
# Out:
#                    turnstile            datetime        station  entries  \
# 0         A002 R051 02-00-00 2018-12-29 03:00:00          59 ST  6889287
# 1         A002 R051 02-00-00 2018-12-29 07:00:00          59 ST  6889299
# 2         A002 R051 02-00-00 2018-12-29 11:00:00          59 ST  6889364
# 3         A002 R051 02-00-00 2018-12-29 15:00:00          59 ST  6889605
# 4         A002 R051 02-00-00 2018-12-29 19:00:00          59 ST  6889966
# ...                      ...                 ...            ...      ...
# 2667716  TRAM2 R469 00-05-01 2020-01-03 04:00:00  RIT-ROOSEVELT     5554
# 2667717  TRAM2 R469 00-05-01 2020-01-03 08:00:00  RIT-ROOSEVELT     5554
# 2667718  TRAM2 R469 00-05-01 2020-01-03 12:00:00  RIT-ROOSEVELT     5554
# 2667719  TRAM2 R469 00-05-01 2020-01-03 16:00:00  RIT-ROOSEVELT     5554
# 2667720  TRAM2 R469 00-05-01 2020-01-03 20:00:00  RIT-ROOSEVELT     5554
#
#            exits  feb_entries  feb_exits
# 0        2335920    2086212.0        0.0
# ...

# %%
id = mar1.loc[0,'turnstile']
id
# Out:
# 'A033 R170 02-00-00'

# %%
mar1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1793 entries, 0 to 1792
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      1793 non-null   int64
#  1   turnstile  1793 non-null   object
#  2   datetime   1793 non-null   datetime64[ns]
#  3   station    1793 non-null   object
#  4   entries    1793 non-null   int64
#  5   exits      1793 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 84.2+ KB

# %%
'14 ST-UNION SQ' in df2.station
# Out:
# False

# %%
id in list(jan1.turnstile)
# Out:
# True

# %%
id in apr1
# Out:
# False

# %%
df2.turnstile.value_counts()
# Out:
# PTH07 R550 00-00-08    841
# R406 R448 00-00-02     611
# R406 R448 00-00-00     611
# R406 R448 00-00-01     606
# H023 R236 00-00-01     605
#                       ...
# PTH19 R549 02-00-08      1
# N316 R267 00-06-00       1
# PTH18 R549 01-02-08      1
# PTH04 R551 00-01-08      1
# PTH10 R547 00-00-08      1
# Name: turnstile, Length: 4994, dtype: int64

# %%
df
# Out:
#            C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0         A002  R051  02-00-00          59 ST  NQR456W      BMT  12/29/2018
# 1         A002  R051  02-00-00          59 ST  NQR456W      BMT  12/29/2018
# 2         A002  R051  02-00-00          59 ST  NQR456W      BMT  12/29/2018
# 3         A002  R051  02-00-00          59 ST  NQR456W      BMT  12/29/2018
# 4         A002  R051  02-00-00          59 ST  NQR456W      BMT  12/29/2018
# ...        ...   ...       ...            ...      ...      ...         ...
# 2667716  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/03/2020
# 2667717  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/03/2020
# 2667718  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/03/2020
# 2667719  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/03/2020
# 2667720  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/03/2020
#
#              TIME     DESC  ENTRIES  \
# ...

# %%
df2.drop(df2.loc[df['DESC']=='RECOVR_AUD'].index, inplace=True)

# %%
df2.columns = df2.columns.str.lower()

# %%
df2.desc.value_counts()
# Out:
# REGULAR       2658197
# RECOVR AUD       9524
# Name: desc, dtype: int64

# %%
df2.drop(df.loc[df2['desc']=='RECOVR AUD'].index, inplace=True)

# %%
df2.drop(columns='desc',inplace=True)

# %%
df2
# Out:
#                    turnstile            datetime        station  entries  \
# 0         A002 R051 02-00-00 2018-12-29 03:00:00          59 ST  6889287
# 1         A002 R051 02-00-00 2018-12-29 07:00:00          59 ST  6889299
# 2         A002 R051 02-00-00 2018-12-29 11:00:00          59 ST  6889364
# 3         A002 R051 02-00-00 2018-12-29 15:00:00          59 ST  6889605
# 4         A002 R051 02-00-00 2018-12-29 19:00:00          59 ST  6889966
# ...                      ...                 ...            ...      ...
# 2667716  TRAM2 R469 00-05-01 2020-01-03 04:00:00  RIT-ROOSEVELT     5554
# 2667717  TRAM2 R469 00-05-01 2020-01-03 08:00:00  RIT-ROOSEVELT     5554
# 2667718  TRAM2 R469 00-05-01 2020-01-03 12:00:00  RIT-ROOSEVELT     5554
# 2667719  TRAM2 R469 00-05-01 2020-01-03 16:00:00  RIT-ROOSEVELT     5554
# 2667720  TRAM2 R469 00-05-01 2020-01-03 20:00:00  RIT-ROOSEVELT     5554
#
#            exits
# 0        2335920
# 1        2335936
# 2        2336038
# 3        2336101
# ...

# %%
'59 ST' in list(jan1.station.unique())
# Out:
# False

# %%
df2
# Out:
#                    turnstile            datetime        station  entries  \
# 0         A002 R051 02-00-00 2018-12-29 03:00:00          59 ST  6889287
# 1         A002 R051 02-00-00 2018-12-29 07:00:00          59 ST  6889299
# 2         A002 R051 02-00-00 2018-12-29 11:00:00          59 ST  6889364
# 3         A002 R051 02-00-00 2018-12-29 15:00:00          59 ST  6889605
# 4         A002 R051 02-00-00 2018-12-29 19:00:00          59 ST  6889966
# ...                      ...                 ...            ...      ...
# 2667716  TRAM2 R469 00-05-01 2020-01-03 04:00:00  RIT-ROOSEVELT     5554
# 2667717  TRAM2 R469 00-05-01 2020-01-03 08:00:00  RIT-ROOSEVELT     5554
# 2667718  TRAM2 R469 00-05-01 2020-01-03 12:00:00  RIT-ROOSEVELT     5554
# 2667719  TRAM2 R469 00-05-01 2020-01-03 16:00:00  RIT-ROOSEVELT     5554
# 2667720  TRAM2 R469 00-05-01 2020-01-03 20:00:00  RIT-ROOSEVELT     5554
#
#            exits
# 0        2335920
# 1        2335936
# 2        2336038
# 3        2336101
# ...

# %%
import datetime as dt

# %%
df2.datetime =  dt.fromtimestamp(df2.datetime)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-523-c445483effd8> in <module>
# ----> 1 df2.datetime =  dt.fromtimestamp(df2.datetime)
#
# AttributeError: module 'datetime' has no attribute 'fromtimestamp'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2667721 entries, 0 to 2667720
# Data columns (total 11 columns):
#  #   Column                                                                Dtype
# ---  ------                                                                -----
#  0   C/A                                                                   object
#  1   UNIT                                                                  object
#  2   SCP                                                                   object
#  3   STATION                                                               object
#  4   LINENAME                                                              object
#  5   DIVISION                                                              object
#  6   DATE                                                                  object
#  7   TIME                                                                  object
# ...

# %%
df3 =df.drop(df.loc[df['DESC']=='RECOVR AUD'].index)

# %%
df3['dow'] = pd.to_datetime(df3.DATE).dt.dayofweek

# %%
df3.columns = df3.columns.str.lower()

# %%
df3.time = pd.to_datetime(df3.time)

# %%
df3.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2658197 entries, 0 to 2667720
# Data columns (total 12 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   c/a       object
#  1   unit      object
#  2   scp       object
#  3   station   object
#  4   linename  object
#  5   division  object
#  6   date      datetime64[ns]
#  7   time      datetime64[ns]
#  8   desc      object
#  9   entries   int64
#  10  exits     int64
#  11  dow       int64
# dtypes: datetime64[ns](2), int64(3), object(7)
# memory usage: 263.6+ MB

# %%
df2 = pd.to_datetime(df2.datetime)

# %%
df2.loc[0]
# Out:
# Timestamp('2018-12-29 03:00:00')

# %%
df2.reindex(cols)
# Out:
# index              NaT
# turnstile          NaT
# datetime           NaT
# station            NaT
# starting_entries   NaT
# starting_exits     NaT
# feb_entries        NaT
# feb_exits          NaT
# march_entries      NaT
# march_exits        NaT
# Name: datetime, dtype: datetime64[ns]

# %%
df2
# Out:
#                station linename division        date      time     desc  \
# 0                59 ST  NQR456W      BMT  12/29/2018  03:00:00  REGULAR
# 1                59 ST  NQR456W      BMT  12/29/2018  07:00:00  REGULAR
# 2                59 ST  NQR456W      BMT  12/29/2018  11:00:00  REGULAR
# 3                59 ST  NQR456W      BMT  12/29/2018  15:00:00  REGULAR
# 4                59 ST  NQR456W      BMT  12/29/2018  19:00:00  REGULAR
# ...                ...      ...      ...         ...       ...      ...
# 2667716  RIT-ROOSEVELT        R      RIT  01/03/2020  04:00:00  REGULAR
# 2667717  RIT-ROOSEVELT        R      RIT  01/03/2020  08:00:00  REGULAR
# 2667718  RIT-ROOSEVELT        R      RIT  01/03/2020  12:00:00  REGULAR
# 2667719  RIT-ROOSEVELT        R      RIT  01/03/2020  16:00:00  REGULAR
# 2667720  RIT-ROOSEVELT        R      RIT  01/03/2020  20:00:00  REGULAR
#
#          entries    exits          turnstile
# 0        6889287  2335920   A002R05102-00-00
# ...

# %%
df2 = df.copy

# %%
df2 = df

# %%
cols = list(df2)

# %%
df2.columns = df2.columns.str.strip()

# %%
df2.columns = df2.columns.str.lower()

# %%
df2.rename(columns={'c/a': 'ca'},inplace=True)

# %%
df2['turnstile'] = (df2.ca + df2.unit + df2.scp)

# %%
df2.drop(columns = ['ca','unit','scp'], inplace=True)

# %%
cols = list(df2.columns)

# %%
cols.insert(0,(cols.pop(cols.index('turnstile'))))

# %%
df2=df[cols]
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2667721 entries, 0 to 2667720
# Data columns (total 9 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   turnstile  object
#  1   station    object
#  2   linename   object
#  3   division   object
#  4   date       object
#  5   time       object
#  6   desc       object
#  7   entries    int64
#  8   exits      int64
# dtypes: int64(2), object(7)
# memory usage: 183.2+ MB

# %%
df2.date = pd.to_datetime(df2.date)
df2.time = pd.to_datetime(df2.time)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2658197 entries, 0 to 2667720
# Data columns (total 6 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   turnstile  object
#  1   station    object
#  2   date       datetime64[ns]
#  3   time       datetime64[ns]
#  4   entries    int64
#  5   exits      int64
# dtypes: datetime64[ns](2), int64(2), object(2)
# memory usage: 142.0+ MB

# %%
df2.drop(df2.loc[df['desc']=='RECOVR AUD'].index, inplace=True)

# %%
df2.drop(columns = ['linename','division','desc'],inplace=True)

# %%
df3 = df2.date.resample('D').max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-622-72c300945edd> in <module>
# ----> 1 df3 = df2.date.resample('D').max()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8075
#    8076         axis = self._get_axis_number(axis)
# -> 8077         return get_resampler(
#    8078             self,
#    8079             freq=rule,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/resample.py in get_resampler(obj, kind, **kwds)
#    1267     """
#    1268     tg = TimeGrouper(**kwds)
# -> 1269     return tg._get_resampler(obj, kind=kind)
#    1270
#    1271
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/resample.py in _get_resampler(self, obj, kind)
# ...

# %%
df2.set_index(df2.date,inplace=True)
df2.resample('D')

# %%
df.groupby(['turnstile']).head()
# Out:
#               station linename division        date      time     desc  \
# 0               59 ST  NQR456W      BMT  12/29/2018  03:00:00  REGULAR
# 1               59 ST  NQR456W      BMT  12/29/2018  07:00:00  REGULAR
# 2               59 ST  NQR456W      BMT  12/29/2018  11:00:00  REGULAR
# 3               59 ST  NQR456W      BMT  12/29/2018  15:00:00  REGULAR
# 4               59 ST  NQR456W      BMT  12/29/2018  19:00:00  REGULAR
# ...               ...      ...      ...         ...       ...      ...
# 2647168  ASTORIA BLVD      NQW      BMT  12/28/2019  03:00:00  REGULAR
# 2647169  ASTORIA BLVD      NQW      BMT  12/28/2019  07:00:00  REGULAR
# 2647170  ASTORIA BLVD      NQW      BMT  12/28/2019  07:18:01  REGULAR
# 2647171  ASTORIA BLVD      NQW      BMT  12/28/2019  11:00:00  REGULAR
# 2647172  ASTORIA BLVD      NQW      BMT  12/28/2019  15:00:00  REGULAR
#
#          entries    exits         turnstile
# 0        6889287  2335920  A002R05102-00-00
# ...

# %%
'12/31/2019' in list(df.date)
# Out:
# True

# %%
df.date.resample('m')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-655-3dc1ea6a4ea4> in <module>
# ----> 1 df.date.resample('m')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8075
#    8076         axis = self._get_axis_number(axis)
# -> 8077         return get_resampler(
#    8078             self,
#    8079             freq=rule,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/resample.py in get_resampler(obj, kind, **kwds)
#    1267     """
#    1268     tg = TimeGrouper(**kwds)
# -> 1269     return tg._get_resampler(obj, kind=kind)
#    1270
#    1271
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/resample.py in _get_resampler(self, obj, kind)
# ...

# %%
df4 = (df.set_index(['date']))

# %%
df4.resample('M')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-664-dbe79b617be0> in <module>
# ----> 1 df4.resample('M')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8075
#    8076         axis = self._get_axis_number(axis)
# -> 8077         return get_resampler(
#    8078             self,
#    8079             freq=rule,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/resample.py in get_resampler(obj, kind, **kwds)
#    1267     """
#    1268     tg = TimeGrouper(**kwds)
# -> 1269     return tg._get_resampler(obj, kind=kind)
#    1270
#    1271
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/resample.py in _get_resampler(self, obj, kind)
# ...

# %%
df4.reset_index(inplace=True)

# %%
df4
# Out:
#                date        station linename division      time     desc  \
# 0        12/29/2018          59 ST  NQR456W      BMT  03:00:00  REGULAR
# 1        12/29/2018          59 ST  NQR456W      BMT  07:00:00  REGULAR
# 2        12/29/2018          59 ST  NQR456W      BMT  11:00:00  REGULAR
# 3        12/29/2018          59 ST  NQR456W      BMT  15:00:00  REGULAR
# 4        12/29/2018          59 ST  NQR456W      BMT  19:00:00  REGULAR
# ...             ...            ...      ...      ...       ...      ...
# 2667716  01/03/2020  RIT-ROOSEVELT        R      RIT  04:00:00  REGULAR
# 2667717  01/03/2020  RIT-ROOSEVELT        R      RIT  08:00:00  REGULAR
# 2667718  01/03/2020  RIT-ROOSEVELT        R      RIT  12:00:00  REGULAR
# 2667719  01/03/2020  RIT-ROOSEVELT        R      RIT  16:00:00  REGULAR
# 2667720  01/03/2020  RIT-ROOSEVELT        R      RIT  20:00:00  REGULAR
#
#          entries    exits          turnstile
# 0        6889287  2335920   A002R05102-00-00
# ...

# %%
df4.date = pd.to_datetime(df4.date)
df4.time = pd.to_datetime(df4.time)

# %%
df4.set_index(df4.date,inplace=True)

# %%
df4
# Out:
#                  date        station linename division                time  \
# date
# 2018-12-29 2018-12-29          59 ST  NQR456W      BMT 2021-03-30 03:00:00
# 2018-12-29 2018-12-29          59 ST  NQR456W      BMT 2021-03-30 07:00:00
# 2018-12-29 2018-12-29          59 ST  NQR456W      BMT 2021-03-30 11:00:00
# 2018-12-29 2018-12-29          59 ST  NQR456W      BMT 2021-03-30 15:00:00
# 2018-12-29 2018-12-29          59 ST  NQR456W      BMT 2021-03-30 19:00:00
# ...               ...            ...      ...      ...                 ...
# 2020-01-03 2020-01-03  RIT-ROOSEVELT        R      RIT 2021-03-30 04:00:00
# 2020-01-03 2020-01-03  RIT-ROOSEVELT        R      RIT 2021-03-30 08:00:00
# 2020-01-03 2020-01-03  RIT-ROOSEVELT        R      RIT 2021-03-30 12:00:00
# 2020-01-03 2020-01-03  RIT-ROOSEVELT        R      RIT 2021-03-30 16:00:00
# 2020-01-03 2020-01-03  RIT-ROOSEVELT        R      RIT 2021-03-30 20:00:00
#
#                desc  entries    exits          turnstile
# ...

# %%
df
# Out:
#                station linename division        date      time     desc  \
# 0                59 ST  NQR456W      BMT  12/29/2018  03:00:00  REGULAR
# 1                59 ST  NQR456W      BMT  12/29/2018  07:00:00  REGULAR
# 2                59 ST  NQR456W      BMT  12/29/2018  11:00:00  REGULAR
# 3                59 ST  NQR456W      BMT  12/29/2018  15:00:00  REGULAR
# 4                59 ST  NQR456W      BMT  12/29/2018  19:00:00  REGULAR
# ...                ...      ...      ...         ...       ...      ...
# 2667716  RIT-ROOSEVELT        R      RIT  01/03/2020  04:00:00  REGULAR
# 2667717  RIT-ROOSEVELT        R      RIT  01/03/2020  08:00:00  REGULAR
# 2667718  RIT-ROOSEVELT        R      RIT  01/03/2020  12:00:00  REGULAR
# 2667719  RIT-ROOSEVELT        R      RIT  01/03/2020  16:00:00  REGULAR
# 2667720  RIT-ROOSEVELT        R      RIT  01/03/2020  20:00:00  REGULAR
#
#          entries    exits          turnstile
# 0        6889287  2335920   A002R05102-00-00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2667721 entries, 0 to 2667720
# Data columns (total 9 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   station    object
#  1   linename   object
#  2   division   object
#  3   date       object
#  4   time       object
#  5   desc       object
#  6   entries    int64
#  7   exits      int64
#  8   turnstile  object
# dtypes: int64(2), object(7)
# memory usage: 183.2+ MB

# %%
df.date = pd.to_datetime(df.date)
df.time = pd.to_datetime(df.time)

# %%
df2 = (df.set_index(df.date))

# %%
df2.turnstile.resample('M').max()
# Out:
# date
# 2018-12-31    TRAM2R46900-05-01
# 2019-01-31    TRAM2R46900-05-01
# 2019-02-28    TRAM2R46900-05-01
# 2019-03-31    TRAM2R46900-05-01
# 2019-04-30    TRAM2R46900-05-01
# 2019-05-31    TRAM2R46900-05-01
# 2019-06-30    TRAM2R46900-05-01
# 2019-07-31    TRAM2R46900-05-01
# 2019-08-31    TRAM2R46900-05-01
# 2019-09-30    TRAM2R46900-05-01
# 2019-10-31    TRAM2R46900-05-01
# 2019-11-30    TRAM2R46900-05-01
# 2019-12-31    TRAM2R46900-05-01
# 2020-01-31    TRAM2R46900-05-01
# Freq: M, Name: turnstile, dtype: object

# %%
list(df2)
# Out:
# ['station',
#  'linename',
#  'division',
#  'date',
#  'time',
#  'desc',
#  'entries',
#  'exits',
#  'turnstile']

# %%
df[df.resample('M')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-702-9d25126cf8af> in <module>
# ----> 1 df[df.resample('M')]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8075
#    8076         axis = self._get_axis_number(axis)
# -> 8077         return get_resampler(
#    8078             self,
#    8079             freq=rule,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/resample.py in get_resampler(obj, kind, **kwds)
#    1267     """
#    1268     tg = TimeGrouper(**kwds)
# -> 1269     return tg._get_resampler(obj, kind=kind)
#    1270
#    1271
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/resample.py in _get_resampler(self, obj, kind)
# ...

# %%
df2 = df.set_index(df.date)

# %%
df2[df2.resample('M')]
# Out:
# /Users/michaelharnett/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-708-03935c82fe89> in <module>
# ----> 1 df2[df2.resample('M')]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ...

# %%
df2[df2.turnstile.resample('M')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-710-9efa0ef441eb> in <module>
# ----> 1 df2[df2.turnstile.resample('M')]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2890
#    2891         # Do we have a (boolean) 1d indexer?
# -> 2892         if com.is_bool_indexer(key):
#    2893             return self._getitem_bool_array(key)
#    2894
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     126         is_array_like(key) and is_extension_array_dtype(key.dtype)
#     127     ):
# --> 128         if key.dtype == np.object_:
#     129             key = np.asarray(key)
#     130
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/resample.py in __getattr__(self, attr)
#     113             return self[attr]
#     114
# ...

# %%
df2.turnstile.resample('M')

# %%
df2[['turnstile','entries']].resample('M').shape()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-719-3b8980687fb0> in <module>
# ----> 1 df2[['turnstile','entries']].resample('M').shape()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/resample.py in __getattr__(self, attr)
#     113             return self[attr]
#     114
# --> 115         return object.__getattribute__(self, attr)
#     116
#     117     def __iter__(self):
#
# AttributeError: 'DatetimeIndexResampler' object has no attribute 'shape'

# %%
df3 = df2.resample('M').agg({'entries': 'max','exits':'max'})

# %%
df2.turnstile.dt.is_month_end
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-727-97f107721a62> in <module>
# ----> 1 df2.turnstile.dt.is_month_end
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5133             or name in self._accessors
#    5134         ):
# -> 5135             return object.__getattribute__(self, name)
#    5136         else:
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
# ...

# %%
df.turnstile.nunique()
# Out:
# 4994

# %%
df2
# Out:
#                   station linename division       date                time  \
# date
# 2018-12-29          59 ST  NQR456W      BMT 2018-12-29 2021-03-30 03:00:00
# 2018-12-29          59 ST  NQR456W      BMT 2018-12-29 2021-03-30 07:00:00
# 2018-12-29          59 ST  NQR456W      BMT 2018-12-29 2021-03-30 11:00:00
# 2018-12-29          59 ST  NQR456W      BMT 2018-12-29 2021-03-30 15:00:00
# 2018-12-29          59 ST  NQR456W      BMT 2018-12-29 2021-03-30 19:00:00
# ...                   ...      ...      ...        ...                 ...
# 2020-01-03  RIT-ROOSEVELT        R      RIT 2020-01-03 2021-03-30 04:00:00
# 2020-01-03  RIT-ROOSEVELT        R      RIT 2020-01-03 2021-03-30 08:00:00
# 2020-01-03  RIT-ROOSEVELT        R      RIT 2020-01-03 2021-03-30 12:00:00
# 2020-01-03  RIT-ROOSEVELT        R      RIT 2020-01-03 2021-03-30 16:00:00
# 2020-01-03  RIT-ROOSEVELT        R      RIT 2020-01-03 2021-03-30 20:00:00
#
#                desc  entries    exits          turnstile
# ...

# %%
df2.iloc[df2.reset_index().groupby(df2.index.to_period('M'))['index'].idxmax()]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-732-983f0a457fff> in <module>
# ----> 1 df2.iloc[df2.reset_index().groupby(df2.index.to_period('M'))['index'].idxmax()]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4853                 # to ndarray and maybe infer different dtype
#    4854                 level_values = _maybe_casted_values(lev, lab)
# -> 4855                 new_obj.insert(0, name, level_values)
#    4856
#    4857         new_obj.index = new_index
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3622         self._ensure_valid_index(value)
#    3623         value = self._sanitize_column(column, value, broadcast=False)
# ...

# %%
df4=df2.drop(columns = 'date',inplace=True)

# %%
df2.iloc[df2.reset_index().groupby(df2.index.to_period('M'))['index'].idxmax()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-739-983f0a457fff> in <module>
# ----> 1 df2.iloc[df2.reset_index().groupby(df2.index.to_period('M'))['index'].idxmax()]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1648                 stacklevel=2,
#    1649             )
# -> 1650         return super().__getitem__(key)
#    1651
#    1652     def _gotitem(self, key, ndim: int, subset=None):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/base.py in __getitem__(self, key)
#     226         else:
#     227             if key not in self.obj:
# --> 228                 raise KeyError(f"Column not found: {key}")
#     229             return self._gotitem(key, ndim=1)
#     230
#
# KeyError: 'Column not found: index'

# %%
df.iloc[df.reset_index().groupby(df.index.to_period('M'))['index'].idxmax()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-741-6c2d73663a2b> in <module>
# ----> 1 df.iloc[df.reset_index().groupby(df.index.to_period('M'))['index'].idxmax()]
#
# AttributeError: 'RangeIndex' object has no attribute 'to_period'

# %%
id = jan1.loc[0,'turnstile']
id
# Out:
# 'A033 R170 02-00-00'

# %%
id in list(jan1.turnstile)
# Out:
# False

# %%
df[df.turnstile==id]
# Out:
# Empty DataFrame
# Columns: [station, linename, division, date, time, desc, entries, exits, turnstile]
# Index: []

# %%
id in list(jan1.turnstile)
# Out:
# True

# %%
df
# Out:
#                station linename division       date                time  \
# 0                59 ST  NQR456W      BMT 2018-12-29 2021-03-30 03:00:00
# 1                59 ST  NQR456W      BMT 2018-12-29 2021-03-30 07:00:00
# 2                59 ST  NQR456W      BMT 2018-12-29 2021-03-30 11:00:00
# 3                59 ST  NQR456W      BMT 2018-12-29 2021-03-30 15:00:00
# 4                59 ST  NQR456W      BMT 2018-12-29 2021-03-30 19:00:00
# ...                ...      ...      ...        ...                 ...
# 2667716  RIT-ROOSEVELT        R      RIT 2020-01-03 2021-03-30 04:00:00
# 2667717  RIT-ROOSEVELT        R      RIT 2020-01-03 2021-03-30 08:00:00
# 2667718  RIT-ROOSEVELT        R      RIT 2020-01-03 2021-03-30 12:00:00
# 2667719  RIT-ROOSEVELT        R      RIT 2020-01-03 2021-03-30 16:00:00
# 2667720  RIT-ROOSEVELT        R      RIT 2020-01-03 2021-03-30 20:00:00
#
#             desc  entries    exits          turnstile
# ...
